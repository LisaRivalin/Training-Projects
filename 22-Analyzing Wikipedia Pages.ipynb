# %% [markdown]
# <h1>
# <center>
# Dataquest Guided Project 22:
# Analyzing Wikipedia Pages
# </center>
# </h1>

# %% [markdown]
# ## Introduction

# %% [markdown]
# This is part of the Dataquest program.
#
# - part of paths **Data Engineer**
#     - Step 2: **Handling Large Data Sets in Python**
#         - Course 2:  **Optimizing Code Performance On Large Datasets **
#             - CPU Bound Programs
#             - I/O Bound Programs
#             - Overcoming The Limitations of Threads
#             - Quickly Analyzing Data With Parallel Processing
#
# As this is a guided project, we are following and deepening the steps suggested by Dataquest. In this project, we will practise working with large datasets in pandas.

# %% [markdown]
# ## Use case : Analyzing Wikipedia Pages

# %% [markdown]
# In this guided project, we will be working with data scraped from [Wikipedia](https://www.wikipedia.org/), a popular online encyclopedia. Wikipedia is maintained by volunteer content contributors and editors who continuously improve content.
#
# In this project, we'll be analyzing 54 megabytes worth of articles to figure out patterns in the Wikipedia writing and content presentation style. The articles were scraped by hitting random pages on Wikipedia, then downloading the contents using the [requests](http://docs.python-requests.org/en/master/) package.
#
# All the data are store in the "wiki" folder.
#
# Our main goals will be to :
# - Extract only the text from the Wikipedia pages, and remove all the HTML and Javascript markup.
# - Remove common page headers and footers from Wikipedia pages
# - Figure out what tags are the most common in Wikipedia pages
# - Figure out patters in the text.

# %% [markdown]
# ## Explore the folder

# %% [markdown]
# First, let's list all of the files in the wiki folder.

# %%
import os
os.listdir("wiki")
# Out:
# ['Furubira_District,_Hokkaido.html',
#  'Valentin_Yanin.html',
#  'Kings_XI_Punjab_in_2014.html',
#  'William_Harvey_Lillard.html',
#  'Radial_Road_3.html',
#  'George_Weldrick.html',
#  'Zgornji_Otok.html',
#  'Blue_Heelers_(season_8).html',
#  'Taggen_Nunatak.html',
#  '1951_National_League_tie-breaker_series.html',
#  'List_of_number-one_singles_of_1993_(Finland).html',
#  'Vrila.html',
#  'William_Henry_Porter.html',
#  'Clive_Brown_(footballer).html',
#  '2010_Karshi_Challenger_%E2%80%93_Singles.html',
#  'Blick_nach_Rechts.html',
#  'Central_District_(Rezvanshahr_County).html',
#  'Gal%C3%A1pagos,_Guadalajara.html',
#  'Campus_of_Texas_A%26M_University.html',
#  'Alexios_Aspietes.html',
#  'Mei_Lanfang.html',
#  'Thalkirchen-Obersendling-Forstenried-F%C3%BCrstenried-Solln.html',
#  'Coalville_Town_railway_station.html',
#  'Gennady_Lesun.html',
#  'Bartrum_Glacier.html',
#  'Victor_S._Mamatey.html',
#  'Gottfried_Keller.html',
#  'Table_Point_Formation.html',
#  'Nobuhiko_Ushiba.html',
#  'Master_of_Space_and_Time.html',
#  'Early_medieval_states_in_Kazakhstan.html',
#  'Eressa_aperiens.html',
#  'Companys,_proc%C3%A9s_a_Catalunya.html',
#  'Myrtle_(sternwheeler).html',
#  'Abanycha_bicolor.html',
#  'Aubrey_Fair.html',
#  'Urban_chicken.html',
#  'Elgin_National_Watch_Company.html',
#  'Goran_Obradovi%C4%87_(footballer,_born_1976).html',
#  'Bluesin%27_Around.html',
#  'Pr%C3%A9liminaires.html',
#  'Antae_temple.html',
#  'Metis_Institute_of_Polytechnic.html',
#  '1953%E2%80%9354_FA_Cup_qualifying_rounds.html',
#  'Sverre_Solberg.html',
#  'John_Reid_(British_Army_officer).html',
#  'List_of_mountains_of_the_Falkland_Islands.html',
#  'Fischli.html',
#  'Aylon_Darwin_Tavella.html',
#  'Sambhaji_Raje_Chhatrapati.html',
#  'Alexander_Rizzoni.html',
#  'Pixley_Township,_Clay_County,_Illinois.html',
#  'Jules_Verne_ATV.html',
#  'Tomohiko_It%C5%8D_(director).html',
#  'Battle_of_Isonzo_(489).html',
#  'Pictogram.html',
#  'Alan_Oakley.html',
#  'Le_Premier_Sexe.html',
#  'Eugamandus_brunneus.html',
#  'Arthur_Norman.html',
#  'Feel_No_Fret.html',
#  'Claire_Danes.html',
#  'Adish_Aggarwala.html',
#  'Egg_coffee.html',
#  'Diplacus_aurantiacus.html',
#  'Sumba%E2%80%93Flores_languages.html',
#  'Justus_Ferdinand_Poggenburg_II.html',
#  'Svendborg_Skibsv%C3%A6rft.html',
#  'Communities_of_Tulu_Nadu.html',
#  'Supermoon.html',
#  'Ron_Harvey_(rugby_union).html',
#  'Olivaceous_flatbill.html',
#  'Javier_Bruses.html',
#  'Mitrella_guerreiroi.html',
#  'Louis_Vivet.html',
#  'Yarkant_County.html',
#  'Mrs._Wilkes%27_Dining_Room.html',
#  'Theonellamide_F.html',
#  'PTPRS.html',
#  'Legge.html',
#  'Constance_D%27Arcy_Mackay.html',
#  'Tom_Buffington.html',
#  'Leuke_Kome.html',
#  'Horace_Pinker.html',
#  'C%27est_la_vie_(Khaled_song).html',
#  'Kelvin_R._Throop.html',
#  'Yemeni_rial.html',
#  'Miss_Guatemala_2008.html',
#  'Merwin_Hodel.html',
#  'A_Beautiful_Valley.html',
#  'H._T._Hackney_Company.html',
#  'Berzeliustinden.html',
#  'John_Nelson_(merchant).html',
#  'Short_Message_service_center.html',
#  'Lebanon_at_the_1980_Winter_Olympics.html',
#  'Streatfeild_family.html',
#  'Kendal_Williams.html',
#  'List_of_women%27s_football_clubs_in_Japan.html',
#  'Tam%C3%A1s_Buday.html',
#  'Jeff_Weise.html',
#  'William_Harper_(South_Carolina).html',
#  '2007%E2%80%9308_Huddersfield_Town_A.F.C._season.html',
#  'Shanghai_Shuffle.html',
#  'Danny_Gray.html',
#  'Platinum_fulminate.html',
#  'Guyana_at_the_2010_Central_American_and_Caribbean_Games.html',
#  'Alpine_skiing_at_the_1994_Winter_Olympics_%E2%80%93_Men%27s_combined.html',
#  'Jeecy-Vea.html',
#  'The_Wire_(JTF-GTMO).html',
#  'Turowo,_Pomeranian_Voivodeship.html',
#  'Mike_Purdy.html',
#  'Hagen_Hauptbahnhof.html',
#  'Patrick_F._Philbin.html',
#  'Ribboned_sweetlips.html',
#  'Endre_Church.html',
#  'Nabil_Baha.html',
#  'Mudramothiram.html',
#  'Schlettau.html',
#  'Ameenapuram.html',
#  'Nathaniel_Merriman.html',
#  '2011_ITU_Duathlon_World_Championships.html',
#  'Mara_Keisling.html',
#  'Ragnar_Gustavsson.html',
#  'William_de_Pembroke.html',
#  'Teskey,_Kyrgyzstan.html',
#  'Mark_Maunder.html',
#  'Wheatland_High_School_(California).html',
#  'Markus_Blutsch.html',
#  'Kristiene_Gong.html',
#  'Punjab_War.html',
#  'Syncretocarpus.html',
#  'Gordon_Bau.html',
#  'Bibliography_of_Niue.html',
#  'Marv_Felderman.html',
#  'Code_page_1023.html',
#  'Discretionary_trust.html',
#  'Cryptographic_primitive.html',
#  'Alex_Kurtzman.html',
#  'William_Samuel_Viner.html',
#  'Nyck_de_Vries.html',
#  'Liga_de_F%C3%BAtbol_Profesional_Boliviano.html',
#  'Scott_McPherson.html',
#  'Kirsten_Klein.html',
#  '2011%E2%80%9312_Western_Collegiate_Hockey_Association_women%27s_ice_hockey_season.html',
#  'List_of_lakes_in_Independence_County,_Arkansas.html',
#  'David_Sands_(psychologist).html',
#  'Beyond_Magnetic.html',
#  'Church_of_the_SubGenius.html',
#  'Vaccinium_padifolium.html',
#  'ZNF644.html',
#  '2005%E2%80%9306_in_Welsh_football.html',
#  'Regina_Pacis_Catholic_Secondary_School.html',
#  'Filip_Pyrochta.html',
#  'Bal%C3%A1zs_Vill%C3%A1m.html',
#  'Gorgopis_subrimosa.html',
#  'Harry_Lynde_Bradley.html',
#  'North_Otago_Astronomical_Society_Observatory.html',
#  'Morgana_King.html',
#  'Don_Parsons_(ice_hockey).html',
#  'Evene.html',
#  'Therese_Maron.html',
#  'Plasnewydd.html',
#  'Belvedere,_London.html',
#  '1958_Wightman_Cup.html',
#  'Bias.html',
#  'Terry_Cox.html',
#  'Heo_Mok.html',
#  'Maple_Jam_Music_Group.html',
#  'Heiko_M%C3%A4rz.html',
#  'Imperial_Venus_(film).html',
#  'Charles_Stuart_(rugby_union).html',
#  'Yarumal.html',
#  'Olive_Dennis.html',
#  'Italy%E2%80%93United_States_relations.html',
#  'Camp_Nelson_Confederate_Cemetery.html',
#  'Treaty_of_Warsaw_(1970).html',
#  'Bill_Widenhouse.html',
#  'Benny_Lee.html',
#  '1898_Colgate_football_team.html',
#  'Caprinia_versicolor.html',
#  'P%C5%82az%C3%B3wka.html',
#  'MoneyHunt.html',
#  'Neville_Hewitt_(American_football).html',
#  'Faces_(Run%E2%80%93D.M.C._song).html',
#  'Dialogue_for_Hungary.html',
#  'Wu_Jin.html',
#  'Kul_Gul.html',
#  'Igor_and_Grichka_Bogdanoff.html',
#  'Tapat%C3%ADo_hot_sauce.html',
#  'Two_House_theology.html',
#  'Tramery.html',
#  'Revolutionary_Vol._1.html',
#  'Gaston_Lane.html',
#  'MobiasBanca.html',
#  'Lectionary_69.html',
#  'Arvind_Gokhale.html',
#  'Thomas_Croci.html',
#  'T%C5%8Dr%C5%8D_nagashi.html',
#  'Medicago_murex.html',
#  'Red-eyed_dove.html',
#  'Jazz_at_the_Plaza_Vol._II.html',
#  'Josef_Mik.html',
#  'AVM_GmbH.html',
#  '2001_Australian_Individual_Speedway_Championship.html',
#  'Mariana_Mazzucato.html',
#  'United_Nations_Security_Council_Resolution_731.html',
#  'Oldfield_Baby_Great_Lakes.html',
#  'Redwater,_Mississippi.html',
#  'Wangerooge-class_tug.html',
#  'Achaea_faber.html',
#  'Ramana,_Pakistan.html',
#  'Charles_Page_(cricketer).html',
#  'Sweeper.html',
#  'Canbelego_County.html',
#  'Wilson_Global_Explorer.html',
#  'Craig_Chester.html',
#  'Derek_Acorah.html',
#  'Wilbraham_%26_Monson_Academy.html',
#  'Mountune_Racing.html',
#  'AB_v_CD.html',
#  'Jack_Goes_Home.html',
#  '2016_Minnesota_Vikings_season.html',
#  'Morning_Glory_(2010_film).html',
#  'Flashmob_(album).html',
#  'I_Marine_Expeditionary_Force.html',
#  'KDDQ.html',
#  'Tim_Spencer_(singer).html',
#  'Suri,_Kerman.html',
#  'Seeking_Gaddafi.html',
#  'Jotedar.html',
#  'Kyokutou_I_Love_You.html',
#  'The_Portal_(community_center).html',
#  'John_C._Freeman_Weather_Museum.html',
#  'Curtiss-Wright_Hangar_(Columbia,_South_Carolina).html',
#  'S%C3%BCderelbe.html',
#  'Mick_Crotty.html',
#  'Juan_Carlos_Pinz%C3%B3n.html',
#  'Now_That%27s_What_I_Call_Music!_55_(U.S._series).html',
#  'Johnny_Morris_(American_football).html',
#  'Lower_Blackburn_Grade_Bridge.html',
#  'Van_Buren,_Ohio.html',
#  'Rules_of_Engagement_(Alexander_novel).html',
#  'The_Wedding_(Sparks_novel).html',
#  'West_Valley,_Washington.html',
#  '2017_Orange_County_Breakers_season.html',
#  'Fureai_kippu.html',
#  'Margo_Reuten.html',
#  'Saladino%27s_Inc.html',
#  'The_Master_Plan_(album).html',
#  'Mark_Baker_(basketball).html',
#  'Zehut.html',
#  'Sol_Eclipse.html',
#  'Para%C3%B1aque_National_High_School,_Don_Galo_Annex.html',
#  '2004_Tuvalu_A-Division.html',
#  'Jonathan_A._Goldstein.html',
#  'Naoise_%C3%93_Muir%C3%AD.html',
#  'F%C3%A9lix_C%C3%A1rdenas.html',
#  '83_(number).html',
#  'SBOA_School_%26_Junior_College.html',
#  'Devil_on_Horseback.html',
#  'Siuniu.html',
#  'Devarampally.html',
#  'SolydXK.html',
#  'Intel_QuickPath_Interconnect.html',
#  'Sierra_Leone_Studies.html',
#  'Harry_Hill_Bandholtz.html',
#  'Bijou,_California.html',
#  'Abdelwahid_Aboud_Mackaye.html',
#  'Equestrian_at_the_1936_Summer_Olympics.html',
#  'Pergamus.html',
#  'Biorock.html',
#  '2016%E2%80%9317_New_Zealand_Football_Championship.html',
#  'Antigonadotropin.html',
#  'Salem-Auburn_Streets_Historic_District.html',
#  'Henrique_da_Silveira.html',
#  'Jane_Wrightson.html',
#  'Gregory_Fortuin.html',
#  'Prisons_in_Bolivia.html',
#  'Ga%C5%A1parci.html',
#  'Paul_Maddrell.html',
#  'Vivian_Prokop.html',
#  'Oued_Tl%C3%A9lat.html',
#  'Paser_Crossword_Stela.html',
#  'Shpolskii_matrix.html',
#  'Bruce_Conte.html',
#  'Old_Mill_Creek,_Illinois.html',
#  'SC_Goldau.html',
#  'Robert_Frederick_Blum.html',
#  'Meydan-e_Jahad_Metro_Station.html',
#  'Sagrai.html',
#  'Falman-County_Acres,_Texas.html',
#  'Sa_Re_Ga_Ma_Pa_Challenge_USA_2008.html',
#  'La_Franja.html',
#  'Estadio_Municipal_Pozoblanco.html',
#  'Unionidae.html',
#  'Corporation_(university).html',
#  '1910_in_literature.html',
#  'Robert_Boehringer.html',
#  'Social_impact_of_YouTube.html',
#  'FC_Khikhani_Khulo.html',
#  'Cobble_Hill,_Brooklyn.html',
#  'The_Lavender_Cowboy.html',
#  'Coup_d%27%C3%A9tat.html',
#  'Tomislav_Erceg.html',
#  'USS_Parris_Island_(AG-72).html',
#  'Meir_Zlotowitz.html',
#  'Awali.html',
#  'Gacharageini.html',
#  'Fortuna_Glacier.html',
#  'Dragnet_(franchise).html',
#  'Winters-Wimberley_House.html',
#  'Ban_On.html',
#  '1915_Montana_football_team.html',
#  'Vijay_Govindarajan.html',
#  'Aiva.html',
#  '2011_Wainwright_Roaming_Buffalo_Classic.html',
#  'Uralochka_Zlatoust.html',
#  'Sybra_preapicemaculata.html',
#  'Papyrus_Oxyrhynchus_56.html',
#  'Promises,_Promises_(Incubus_song).html',
#  'Josh_West.html',
#  'Second_Valley,_South_Australia.html',
#  'Doug_Sahm_and_Band.html',
#  'Hope_7_(album).html',
#  'Mohamed_El-Sayed.html',
#  'Qalat_Kat.html',
#  'Woodward_Dream_Cruise.html',
#  'USS_Goldcrest.html',
#  '2016%E2%80%9317_Little_Rock_Trojans_women%27s_basketball_team.html',
#  'Aniavan.html',
#  'Instrumental.html',
#  'Christopher_Speer.html',
#  'Maniitsoq_structure.html',
#  'Minardi_M185.html',
#  'Millennium_Art_Academy.html',
#  'Australian_Musician_(magazine).html',
#  'Charlton_baronets.html',
#  'Cheddar_Ales.html',
#  'Dewoitine_D.21.html',
#  'List_of_Bellator_MMA_events.html',
#  'Tubular_Bells_II.html',
#  'Touch_FM_(Coventry).html',
#  'Kadamaha.html',
#  'James_L._Hull.html',
#  'Furto_di_sera_bel_colpo_si_spera.html',
#  'Hayes_Township,_Clay_County,_Kansas.html',
#  'Pontefract_by-election,_1941.html',
#  'Meleh_Kabud-e_Sofla.html',
#  'Symeon_Stylites_of_Lesbos.html',
#  'Kellie_Jones.html',
#  'Dominique_Voynet.html',
#  'Mohammad_Reza_Niknahal.html',
#  'Garden-based_learning.html',
#  'Sir_Run_Run_Shaw_Hospital.html',
#  'List_of_Argentine_Primera_Divisi%C3%B3n_transfers_January_2011.html',
#  'Gaetanus_Matthew_Perez.html',
#  'Sudanese_pound.html',
#  'Exploratorium_(film).html',
#  'Foulonia.html',
#  'Reb_Russell.html',
#  'Miltochrista_fuscozonata.html',
#  'Luvvie_Darling.html',
#  'Amborella.html',
#  'List_of_Bratz_episodes.html',
#  'Udi,_Enugu.html',
#  'Canyamars.html',
#  'Kenny_Cordray.html',
#  'Siege_of_Valenciennes_(1793).html',
#  'Santa_Mar%C3%ADa_Yaves%C3%ADa.html',
#  'Baddiewinkle.html',
#  'Chemin_d%27Aylmer.html',
#  'SSR-180,711.html',
#  'David_Solomona.html',
#  'Rally_for_Democracy_and_Progress_(Benin).html',
#  'I_Am_Cold.html',
#  'Sarah_Blakley-Cartwright.html',
#  'Rubber_Biscuit.html',
#  'Heald_Green.html',
#  'Charles_Smith_Wilcox.html',
#  'Swathi_Chinukulu.html',
#  'Noise_(song).html',
#  'Maukala.html',
#  'Hilyard_Robinson.html',
#  'Shellie_Morris.html',
#  'Bob_Bass.html',
#  'Diphilus_(physician).html',
#  'Arun_K._Pati.html',
#  'Agaritine_gamma-glutamyltransferase.html',
#  'Sky_Regional_Airlines.html',
#  'Wilhelm_August_Graah.html',
#  'Avenira.html',
#  'Slade_School_of_Fine_Art.html',
#  'Zane_Radcliffe.html',
#  'Devitt_Insurance.html',
#  'Lincoln_Clarkes.html',
#  'Panhandle%E2%80%93Plains_Historical_Museum.html',
#  'Bahmanabad-e_Olya.html',
#  'Tarsila_do_Amaral.html',
#  'Ioana_Badea.html',
#  'The_Gentleman_Without_a_Residence_(1915_film).html',
#  'Troso_da_Monza.html',
#  'Walter_of_Durham.html',
#  'James_Wilkes_Maurice.html',
#  'Section_20_of_the_Canadian_Charter_of_Rights_and_Freedoms.html',
#  'Ferdinand_Mainzer.html',
#  'Keeled_sideband.html',
#  'Palio_zosterae.html',
#  'Lydia_Villa-Komaroff.html',
#  'Henri_Braqueni%C3%A9.html',
#  'Nickel(II)_hydroxide.html',
#  'Usher_Gahagan.html',
#  'John_V._G._Posey_House.html',
#  'Kfarhata.html',
#  'James_Alexander_Ulio.html',
#  'De_La_Salle_University_%E2%80%93_Dasmari%C3%B1as.html',
#  'When_You_Loved_Me.html',
#  'Flat_roof.html',
#  'Jack_Wong.html',
#  'The_Love-Girl_and_the_Innocent.html',
#  'Manhattan_Murder_Mystery.html',
#  'DiGiorgio_Corporation.html',
#  'Eugenio_Morelli.html',
#  'Kenneth_Thomas_(cricketer).html',
#  'Mar%C3%ADa_Calder%C3%B3n.html',
#  'James_Magee.html',
#  'Bill_Price_(baseball).html',
#  'Mount_Jim_Crow_National_Park.html',
#  'Avengers_Academy.html',
#  'Scrobipalpa_halophila.html',
#  'Swan_neck_deformity.html',
#  'Chhatrasal.html',
#  'Raymond_II,_Count_of_Toulouse.html',
#  'Macroglossum_pseudoluteata.html',
#  'Antibiotic_use_in_livestock.html',
#  'Omaha_Racers.html',
#  'Syngenor.html',
#  'Mecklenburg_Switzerland_and_Lake_Kummerow_Nature_Park.html',
#  'List_of_largest_chemical_producers.html',
#  'X-Cops_(band).html',
#  'Hannover_Indians.html',
#  'Carlos_Martins_(musician).html',
#  'Women%27s_javelin_throw_world_record_progression.html',
#  'Asparuh_Peak.html',
#  'Robert_K._Zukowski.html',
#  'Gorfion.html',
#  'Marson.html',
#  'I%27ve_Heard_That_Song_Before.html',
#  'Jens_Pauli_Skaalum.html',
#  'Chestnut_pie.html',
#  'Vitaly_Bianki.html',
#  'Coronium_(gastropod).html',
#  'Arnold_Freiherr_von_Biegeleben.html',
#  'Acacia_dermatophylla.html',
#  'Lis_L%C3%B8wert.html',
#  'Typhoon_Hester_(1952).html',
#  'Ugo_Okoye.html',
#  '2014%E2%80%9315_Kansas_State_Wildcats_men%27s_basketball_team.html',
#  'Kokan_Colony.html',
#  'Oleg_Novitskiy.html',
#  'Llwyn-Cus.html',
#  'Wilhelm_Wagenfeld_House.html',
#  'Erigeron_canaani.html',
#  'Eternamente_Romanticos.html',
#  'Lecithocera_sextacta.html',
#  'Arthur_Lelyveld.html',
#  'Bonny_River.html',
#  'Charles_Sears.html',
#  'Ingrid_Guimar%C3%A3es.html',
#  'Jonas_Ar%C4%8Dikauskas.html',
#  'Tonga_national_basketball_team.html',
#  'City_of_Mandaluyong_Science_High_School.html',
#  'Oktyabrsky_District,_Russia.html',
#  'Archibald_Gordon_(British_Army_officer).html',
#  'Kusaka_Station.html',
#  'Plze%C5%88_Zoo.html',
#  'WLSR.html',
#  'Friendship,_Wake_County,_North_Carolina.html',
#  'Wolfgang_Lutz.html',
#  'Curridge.html',
#  'Kendalia,_Texas.html',
#  'Celebrity_doll.html',
#  'Venezuelan_referendum,_1957.html',
#  'Australian_hardcore.html',
#  'Lake_County_Examiner.html',
#  'HMS_Robust.html',
#  '985_Innovative_Platforms_for_Key_Disciplines_Project.html',
#  'Hermann_Nuding.html',
#  'Love,_Sax_and_Flashbacks.html',
#  'Kolound.html',
#  'Ordinary,_Virginia.html',
#  'Kanakomyrtus.html',
#  'Bulbophyllum_biflorum.html',
#  'Copamyntis_infusella.html',
#  'Archiepiscopal_Palace,_Rouen.html',
#  'Charged_Records.html',
#  'Cosmopterix_similis.html',
#  'Jyoti_Raju.html',
#  'Apocephalus_borealis.html',
#  'Bernard-Augustin_Conroy.html',
#  'Ready_or_Not_(Young_JV_album).html',
#  'Indhiya_Jananayaga_Katchi.html',
#  'St._Peter%27s_Church,_Tiberias.html',
#  'Parkgate_railway_station.html',
#  'C11orf30.html',
#  'Mr_Freedom_(fashion).html',
#  'Stade_Municipal_de_Djougou.html',
#  'Suwannee_River_Junior_College.html',
#  'Estelle_v._Smith.html',
#  'Arabic_Toilers%27_Movement.html',
#  'Koevtsi,_Gabrovo_Province.html',
#  'Kentucky_Auditor_election,_2011.html',
#  '2013_FIA_WTCC_Race_of_Russia.html',
#  'Taipa_Houses%E2%80%93Museum.html',
#  'Tobi_trousers.html',
#  'Museum_of_John_Paul_II_Collection.html',
#  'Gbiri-Niragu_language.html',
#  'Virajpet_(Vidhan_Sabha_constituency).html',
#  'List_of_people_from_Bangor,_Maine.html',
#  'One_Night_of_Sin.html',
#  'Cabrini%E2%80%93Green,_Chicago.html',
#  'Ek_Dil_Sau_Afsane.html',
#  'Pustiu_River.html',
#  'Majeepura.html',
#  'Tongyi,_Mingin.html',
#  'Zeiraphera.html',
#  'Benidorm_Bastards.html',
#  'Burmese_shrike.html',
#  'Axel_Revold.html',
#  '2009_World_Junior_Ice_Hockey_Championships_rosters.html',
#  'Qatar_at_the_2013_World_Championships_in_Athletics.html',
#  'Nepal_at_the_2008_Summer_Paralympics.html',
#  'Daniel_Cerone.html',
#  'Alan_Sheehan.html',
#  'Work_domain_analysis.html',
#  'Pochyta.html',
#  'Jarom%C3%ADr_%C5%A0imr.html',
#  'Simon%27s_Town_railway_station.html',
#  'Larvicide.html',
#  'Power_transfer_unit.html',
#  'Crab-eating_frog.html',
#  'Percy_William_Bunting.html',
#  'Meanings_of_minor_planet_names:_440,001%E2%80%93450,000.html',
#  'Chief_Justice_of_New_Zealand.html',
#  'KUMT.html',
#  'Vanavara_Airport.html',
#  'Lord_Howe%27s_action,_or_the_Glorious_First_of_June.html',
#  '55th_parallel_south.html',
#  'Aleksandra_Jagie%C5%82o.html',
#  'Curtis_Whitley.html',
#  'Post_(structural).html',
#  'Lake_Lagunitas.html',
#  'Failing_Office_Building.html',
#  'Carley_State_Park.html',
#  'Puerto_Rico_at_the_2013_World_Aquatics_Championships.html',
#  'Eyes_Galaxies.html',
#  'Kistenuten.html',
#  'Children_of_the_Grave.html',
#  'Bagrat_VI_of_Georgia.html',
#  'Pushkar.html',
#  'List_of_Uzbek_films_of_2014.html',
#  'Konstantin_%22Samokovetsa%22_Dimitrov.html',
#  'Cygany,_Masovian_Voivodeship.html',
#  'KMTZ.html',
#  'Football_Foundation.html',
#  'Ministry_of_Development_Planning_and_Statistics.html',
#  'Caney_Creek_(Matagorda_Bay).html',
#  'Solanum_chilliasense.html',
#  'Ballard_Memorial_High_School.html',
#  'Thanks_Again.html',
#  'Dowell_Philip_O%27Reilly.html',
#  'The_Land_of_the_Dead.html',
#  'Yoshinkan.html',
#  'John_Maitland_(Royal_Navy_officer).html',
#  'Social_dualism.html',
#  'Golabkhvaran.html',
#  'Liebig_Peak.html',
#  'Garrett_Lucash.html',
#  'Medical_Unit,_Self-contained,_Transportable.html',
#  '1st_Strategic_Aerospace_Division.html',
#  'Agnolin.html',
#  'Wren,_Alabama.html',
#  'Roselawn,_Indiana.html',
#  'Brograve_Mill.html',
#  'Ashley,_Wisconsin.html',
#  'Blue_SWAT.html',
#  'HMS_Stratagem_(P234).html',
#  'Poor_Richard%27s_Almanack_(TV_series).html',
#  'Pedro_Checa.html',
#  'Martha_Herbert.html',
#  'Goodnight%E2%80%93Loving_Trail.html',
#  'Adolf_Schulte.html',
#  'Danish_Maritime_Safety_Administration.html',
#  'Kiev_Missal.html',
#  'Don_Raye.html',
#  'Precorrin-6A_reductase.html',
#  'Strawberry_foliar_nematode.html',
#  'St._Paul_University_Iloilo.html',
#  'Roger_Brooke.html',
#  'Doumanaba.html',
#  'H._Larue_Renfroe.html',
#  'Giants%27_grave_of_S%27Ena%27e_Thomes.html',
#  'Crepidula_atrasolea.html',
#  'Sahanpur.html',
#  'Ksar_Nalut.html',
#  'Phong_Th%E1%BA%A1nh_%C4%90%C3%B4ng_A.html',
#  'Martinus_Hamconius.html',
#  'Sanford_Wallace.html',
#  'Gratitud.html',
#  'Al-Midan.html',
#  'Iwaki-Ishikawa_Station.html',
#  'Abraham_Stanyan.html',
#  'U.S._Snowboarding_Race_to_the_Cup.html',
#  'Seminemacheilus.html',
#  'British_Academy_Television_Award_for_Best_Comedy_(Programme_or_Series).html',
#  'FC_Bobruisk.html',
#  '2011_UK_Open_Qualifier_4.html',
#  'Monarch_Mountain.html',
#  'Johnny_B._Moore.html',
#  'Ayish_Bayou.html',
#  'Newton_Stone.html',
#  'Treaty_of_Ryswick.html',
#  'Kenneth_van_Kempen.html',
#  'Progressive_refinement.html',
#  'Zoom_Systems.html',
#  'Panchamrutham.html',
#  'Hoghiz.html',
#  'Peltigera_membranacea.html',
#  'Bazemore,_Alabama.html',
#  'Ovum_Recordings.html',
#  'Dick_Johnson_(clarinetist).html',
#  'Urodilatin.html',
#  'Stephen_Unwin_(director).html',
#  'Columbia_Airport_(Ohio).html',
#  'Shibanov.html',
#  'DWTE-TV.html',
#  'Bifidocarpus.html',
#  'Priscus_of_Epirus.html',
#  'Bibiana_Beglau.html',
#  'Ordinary_singularity.html',
#  'Castle_of_Cardona.html',
#  'Emmanuel_Muhammad.html',
#  'Bulbonaricus.html',
#  'Kelvin_Mbilinyi.html',
#  'Emily_(1964_song).html',
#  'Ricard_Card%C3%BAs.html',
#  'Greg_Halsey-Brandt.html',
#  'Kim_Yong-hwa.html',
#  'Queensland_Music_Festival.html',
#  'Clay_Township,_Clark_County,_Missouri.html',
#  'Liberty_Central_School_District.html',
#  'Kamakshyanagar.html',
#  'S%C3%A3o_Sebasti%C3%A3o_do_Alto.html',
#  'Kattukukke.html',
#  'Tischofer_Cave.html',
#  'Rob_Jones_(footballer,_born_1971).html',
#  'Embraer_Unidade_Gavi%C3%A3o_Peixoto_Airport.html',
#  'Barren_vegetation.html',
#  'Burbridge_Creek.html',
#  'Bye!_My_Boy!.html',
#  'Phil_Spence.html',
#  'Ronald_McCaffer.html',
#  'Macy_conferences.html',
#  'Belgium_women%27s_national_field_hockey_team.html',
#  'Dalian_Road_Station.html',
#  'Antonio_de_Zayas_(bishop).html',
#  'Oldham_Metropolitan_Borough_Council_election,_2000.html',
#  'Hideki_Kase.html',
#  'Acceptance_(Heroes).html',
#  'Enamul_Haque_(cricketer,_born_1966).html',
#  'RF_microwave_CAE_CAD.html',
#  'Ego_Dominus_Tuus.html',
#  'High_Efficiency_Image_File_Format.html',
#  'New_York_Women_Composers,_Inc..html',
#  'Newfoundland_general_election,_1848.html',
#  'Lungujja.html',
#  'Smeaton,_East_Lothian.html',
#  'Government_Polytechnic_Nagriya_Mod_Etah.html',
#  'Ma_Sen.html',
#  'Phenacobius_catostomus.html',
#  'Norderbrarup.html',
#  'Octomeria_lithophila.html',
#  'Joint_Committee_for_Traceability_in_Laboratory_Medicine.html',
#  'Yuga_(film).html',
#  'Clay_Research_Award.html',
#  'Kreslyuvtsi.html',
#  '33rd_New_Jersey_Volunteer_Infantry.html',
#  'Steinkjersannan.html',
#  'Carthage,_Cincinnati.html',
#  'Senapati_district.html',
#  'Frost_Township,_Michigan.html',
#  'Bay_of_Concepci%C3%B3n.html',
#  'Chhaparband_(Muslim).html',
#  'Guaricana_National_Park.html',
#  'Challenger_Banque_Nationale_de_Drummondville.html',
#  'Appa_(film).html',
#  'Ben_H._Williams.html',
#  'Hypocysta_angustata.html',
#  'Copenhagen_Skatepark.html',
#  'Saratoga_Automobile_Museum.html',
#  'Madhuri_Desai.html',
#  'Athletics_at_the_1994_Commonwealth_Games_%E2%80%93_Men%27s_pole_vault.html',
#  'Odder.html',
#  'Aldona_Orman.html',
#  'Vancouver_Furious_George.html',
#  'Havnar_R%C3%B3%C3%B0rarfelag.html',
#  'Dextran_1.html',
#  'HD_90156.html',
#  'WFGI-FM.html',
#  'Oculo-respiratory_syndrome.html',
#  'Zhongxing_Guesthouse.html',
#  '1988_State_of_Origin_series.html',
#  'Hemiargyropsis_frontalis.html',
#  'The_Audacity_to_Podcast.html',
#  'List_of_Polish_consorts.html',
#  'Third_Saturday_in_October.html',
#  'Antipater_of_Thessalonica.html',
#  'Santa_Maria_Imbaro.html',
#  'Brownfield_(software_development).html',
#  'George_Joseph_Trapp.html',
#  'Russell_Road_(Ontario).html',
#  'Maneswar_Brahma.html',
#  'Robin_Brooke.html',
#  '100_Greatest_Romanians.html',
#  'Cristian_Berdeja.html',
#  'King_Parker_House.html',
#  'Al-Nurayn_Mosque.html',
#  'John_Shaw_Rennie.html',
#  'Sobolewo,_Wysokie_Mazowieckie_County.html',
#  'Meneng_Constituency.html',
#  'List_of_Spaghetti_Western_films.html',
#  'Paul_Kenny_(politician).html',
#  'Luca_Luciano.html',
#  'Cannabis_in_Spain.html',
#  'VSX2.html',
#  'Varsity_College.html',
#  'Fahy,_County_Mayo.html',
#  'Keegan_Pereira_(footballer).html',
#  'Eudonia_notozeucta.html',
#  'Pirama.html',
#  'Shinpei_Matsushita.html',
#  'Boardman_Township,_Mahoning_County,_Ohio.html',
#  'Anton_von_Troeltsch.html',
#  'Vang_stone.html',
#  'Heinz_Inniger.html',
#  'Marion_Rockefeller_Weber.html',
#  'Abdulla_Majid_Al_Naimi.html',
#  'The_Future_(film).html',
#  'Fusinus_carvalhoriosi.html',
#  'List_of_Nymphaeales_of_Montana.html',
#  'Weiser_River.html',
#  'Elzear_Torreggiani.html',
#  'Scarlet_wrasse.html',
#  'Svinjare.html',
#  'G.O.Y.A._(Gunz_Or_Yay_Available).html',
#  'Switzerland_at_the_1992_Winter_Olympics.html',
#  'Chef_Wan.html',
#  'Viva_Villa!.html',
#  'Jon_Mullich.html',
#  'Clear_Creek_Township,_Cooper_County,_Missouri.html',
#  'A_Sport_and_a_Pastime.html',
#  'The_Right_Kinda_Lover.html',
#  'Plains,_Kansas.html',
#  'Baadj.html',
#  'George_Ellicott.html',
#  'Cortile_del_Belvedere.html',
#  'Mick_Kelly_(Australian_footballer).html',
#  'Somarasampettai.html',
#  'David_Jesson.html',
#  '%C5%8Cnog%C5%8D_Station.html',
#  'Nuno_Leal_Maia.html',
#  'Battle_of_Wattignies.html',
#  'Saravan,_Gilan.html',
#  'Colchester_Village_Historic_District.html',
#  'Watsonville_Junction,_California.html',
#  'Hayateumi_Hidehito.html',
#  'Oliver_Twist_(1912_American_film).html',
#  'Omar_Onsi.html',
#  'Utiel-Requena.html',
#  'Volume_One_(The_West_Coast_Pop_Art_Experimental_Band_album).html',
#  'Pozna%C5%84_Wola_railway_station.html',
#  'ISMACryp.html',
#  'Mirisah.html',
#  'USS_Impeccable_(AM-320).html',
#  'Bengt_Forsberg.html',
#  'Irihirose_Station.html',
#  'A_Month_of_Sundays_(miniseries).html',
#  'Teiji_Ito.html',
#  'Robert_E._Lee_(FCC).html',
#  'Giardini_Margherita.html',
#  'Upper_Beaches.html',
#  'Minister_of_Foreign_Affairs_(Egypt).html',
#  'Italian_submarine_Comandante_Fa%C3%A0_di_Bruno.html',
#  'Christine_Gardner.html',
#  'Durham_Women%27s_F.C..html',
#  'USS_Rose_Mary_(SP-1216).html',
#  'Shoreyjeh-ye_Do.html',
#  '%C3%89cole_des_Mines_de_Douai.html',
#  'Luciano_Mercante.html',
#  'Jeff_Boyd.html',
#  'Abbeville_Sluggers.html',
#  'East_Down_(Northern_Ireland_Parliament_constituency).html',
#  'Russian_Cultural_Centre_(Lviv).html',
#  'Morten_Rutkj%C3%A6r.html',
#  'Du%C5%A1anovo.html',
#  'Bowie_Race_Track.html',
#  'Gemma_Doyle_(politician).html',
#  'Thornton-le-Beans.html',
#  'Tommy_Hunter_(baseball).html',
#  'S%C3%B8rli.html',
#  'Frithjof_Schmidt.html',
#  'ARA_Garibaldi.html',
#  'How_Can_We_Hang_On_to_a_Dream%3F.html',
#  'Schwobsheim.html',
#  'Arrondissements_of_the_Yvelines_department.html',
#  'L._Fry.html',
#  'Hepatitis_B_virus.html',
#  'Jordan_Steel.html',
#  'Central_Luzon.html',
#  'Jack_Graham_(pastor).html',
#  'Sentences_(composition).html',
#  'Tropical_sprue.html',
#  'Elisa_von_der_Recke.html',
#  'Neurotica.html',
#  'Roxbury_Presbyterian_Church.html',
#  'Moosavi_Peace_Formula.html',
#  'Acrolophus_simulatus.html',
#  'Dennis_Chapman.html',
#  'Uruguayan_constitutional_referendum,_2014.html',
#  'Peter_Collingwood.html',
#  'List_of_molecular_graphics_systems.html',
#  'MOUSE_DHI.html',
#  'Hexachaeta_colombiana.html',
#  'Sot%C4%81panna.html',
#  '2015%E2%80%9316_Washington_Huskies_men%27s_basketball_team.html',
#  'Oligocentris_deciusalis.html',
#  '2008_Fed_Cup_World_Group_II.html',
#  'Camp_Liberty_killings.html',
#  'Hemet_Public_Library.html',
#  'Lin_Chia-yu.html',
#  'Omiodes_iridias.html',
#  'Shigeo_Kurata.html',
#  'Arthur_L._Aidala.html',
#  'Clocking_Out_Is_for_Suckers.html',
#  'List_of_gold_medalists_at_2006_South_Asian_Games.html',
#  'Gew%C3%A4chshaus_f%C3%BCr_tropische_Nutzpflanzen.html',
#  'The_Purpose_Driven_Church.html',
#  'Brendan_Foster.html',
#  'I%27m_Walking_Behind_You.html',
#  'Glinka_(crater).html',
#  'Larry_Brooks.html',
#  'Socket_423.html',
#  'Double_Wing_Attack.html',
#  'Arkansas_Highway_178.html',
#  'Taylour_Paige.html',
#  'Fraser_Lake_Airport.html',
#  'Potheri_village,_Kanchipuram.html',
#  'Pedro_Machuca.html',
#  'Roll%27s_partridge.html',
#  'Nejat_Alp.html',
#  'Checkerspot_(magazine).html',
#  'Functoid.html',
#  'Manitoba_general_election,_1896.html',
#  'Roman_Catholic_Diocese_of_Cervia.html',
#  'Lopez_v._Davis.html',
#  'Coenaculum_secundum.html',
#  'Football_at_the_National_Games_of_China.html',
#  'Vojin_%C4%86etkovi%C4%87.html',
#  'Sibling_Revelry.html',
#  'Isaac_Gr%C3%BCnewald.html',
#  'Waldoboro_(CDP),_Maine.html',
#  'Cecyl%C3%B3wka-Brz%C3%B3zka.html',
#  'List_of_birds_of_Malta.html',
#  '2009_English_cricket_season.html',
#  'Banovina_of_Croatia.html',
#  'Dakar_2:_The_World%27s_Ultimate_Rally.html',
#  'Anthony_Marten.html',
#  'Arcadio_Gonz%C3%A1lez.html',
#  'Boogie_Bunnies.html',
#  'Roque_P%C3%A9rez_Partido.html',
#  'Andrei_Gamalyan.html',
#  'Mykines,_Greece.html',
#  'Dresden-Plauen_railway_station.html',
#  'Kailas_Pal.html',
#  'Bad_Luck_(Social_Distortion_song).html',
#  'I,_Q_(book_series).html',
#  'Julien_Boisselier.html',
#  'Turkish_Men%27s_Volleyball_Championship.html',
#  'Joint_Social_Welfare_Institute.html',
#  'The_Summer_King.html',
#  'Burnin%27_Sneakers.html',
#  'Chapel_of_Mercy,_Monaco-Ville.html',
#  'Jazz_in_Turkey.html',
#  'Burnley_Borough_Council_election,_2011.html',
#  'National_Register_of_Historic_Places_listings_in_Allen_Parish,_Louisiana.html',
#  'Luiz_Henrique_Santos.html',
#  'Yasid.html',
#  '2001_NCAA_Division_I_Field_Hockey_Championship.html',
#  'Ctenodes_zonata.html',
#  'EDP_Sarichioi_Wind_Farm.html',
#  'Carte_Imagine%27R.html',
#  'Holly_Golightly_(comics).html',
#  'Johann_Christoph_Hoffbauer.html',
#  'Matthew_Liptak.html',
#  'Programa_Mejorando_tu_Autoestima.html',
#  'Philaeus.html',
#  'Kate_Harwood.html',
#  'Baltic_Peak.html',
#  'Westchester,_Los_Angeles.html',
#  'Laredo_Colombia_Solidarity_Port_of_Entry.html',
#  '104th_Logistic_Support_Brigade_(United_Kingdom).html',
#  'Pichoy_Airfield.html',
#  'Wreck_Island_Natural_Area_Preserve.html',
#  'Desmiphora_bijuba.html',
#  'Webb_Dock_railway_line.html',
#  'Helena_Nyblom.html',
#  'Hall_of_Mental_Cultivation.html',
#  'John_Whewell.html',
#  '2014%E2%80%9315_Albanian_Third_Division.html',
#  'Gulliver_Mickey.html',
#  'Henry_Horace_Williams.html',
#  'Hebden_Bridge_Picture_House.html',
#  'Marie-Jos%C3%A8phe_Jude.html',
#  'Circus_Avenue.html',
#  'Kettu_Kalyanam.html',
#  'Union_United_Church.html',
#  'Bill_Overstreet.html',
#  'Urs_Burkart.html',
#  'The_K_of_D.html',
#  'Gandigwad.html',
#  'Kentucky_Theater.html',
#  'USS_General_Putnam_(1857).html',
#  'George_Jones_(bishop).html',
#  'United_Nations_Security_Council_Resolution_1923.html',
#  'The_Hackensaw_Boys.html',
#  'Harry_Sacksioni.html',
#  'David_Beasley.html',
#  'Piracy_on_Falcon_Lake.html',
#  'Mammoth_Unified_School_District.html',
#  'Eggerberg_railway_station.html',
#  'Tillandsia_intermedia.html',
#  'Town_Yetholm.html',
#  'S%27portable_Scoreboards.html',
#  'Sparganothis_saracana.html',
#  'Smilax_laurifolia.html',
#  'Taylor_Williamson.html',
#  'Epropetes_metallica.html',
#  'Melanolagus_bericoides.html',
#  'BBCH-scale_(rice).html',
#  'La_Roca_de_la_Sierra.html',
#  'Russian_Party_in_Estonia.html',
#  'Henry_Louis_Larsen.html',
#  'Torovirinae.html',
#  'Moses_Hardy.html',
#  '1896_Indiana_Hoosiers_football_team.html',
#  'Els_Dottermans.html',
#  'Epichorista.html',
#  'Ownership_of_Rangers_F.C..html',
#  'Clinton_Engineer_Works.html',
#  'It%27s_Just_My_Funny_Way_of_Laughin%27.html',
#  'The_Showdown_Effect.html',
#  'My_Life_(Billy_Joel_song).html',
#  'Ramo_Stott.html',
#  'Geomancer_(comics).html',
#  'Enrique_Morales.html',
#  'Linowiec,_Kuyavian-Pomeranian_Voivodeship.html',
#  'Triptolemus_Evrychou.html',
#  'Claudia_Neidig.html',
#  'Keshav_Ginde.html',
#  'Cyclohexane_conformation.html',
#  'Dean_Kukan.html',
#  'List_of_Carboniferous_tetrapods.html',
#  'Sol_Orwell.html',
#  'Lucius_Allen_(politician).html',
#  'Elio_Calderini.html',
#  'Demographics_of_American_Samoa.html',
#  'Middle_Park,_Victoria.html',
#  'Peringiella_denticulata.html',
#  'Y%C3%AAn_B%C3%A1i.html',
#  'Young_Finnish_Party.html',
#  'Rudy:_The_Rudy_Giuliani_Story.html',
#  'Dysgonia_pudica.html',
#  'Klaus_Gerwien.html',
#  'Lee_Henderson_Watkins.html',
#  '%C3%89taule.html',
#  'Sabari.html',
#  'Timothy_Wanyonyi_Wetangula.html',
#  'Ivo_Siromahov.html',
#  'John_Jephson.html',
#  'Land_%26_Water_Australia.html',
#  'Shabbir_Kumar.html',
#  'Sylvia_Moss.html',
#  'West_Park_Bridge.html',
#  'Imperial_amazon.html',
#  '16th_Virginia_Infantry.html',
#  'North_Coast_(RTA_Rapid_Transit_station).html',
#  'Alex_McEachern.html',
#  'Kate_Quarrie.html',
#  'Cyclone_Gamede.html',
#  'William_McDonald_(Australian_politician).html']

# %% [markdown]
# Let's count up the number of files in this folder:

# %%
len(os.listdir("wiki"))
# Out:
# 999

# %% [markdown]
# Let's now display a single file from the wiki folder to look at the raw HTML :

# %%
with open("wiki/The_Land_of_the_Dead.html") as f: 
    file = f.read()
print(file)
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" lang="en" dir="ltr">
# <head>
# <meta charset="UTF-8"/>
# <title>The Land of the Dead - Wikipedia</title>
# <script>document.documentElement.className = document.documentElement.className.replace( /(^|\s)client-nojs(\s|$)/, "$1client-js$2" );</script>
# <script>(window.RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"The_Land_of_the_Dead","wgTitle":"The Land of the Dead","wgCurRevisionId":754928354,"wgRevisionId":754928354,"wgArticleId":1633029,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Fifth Doctor audio plays","2000 audio plays"],"wgBreakFrames":false,"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgMonthNamesShort":["","Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"wgRelevantPageName":"The_Land_of_the_Dead","wgRelevantArticleId":1633029,"wgRequestId":"WK0vBgpAIC4AAE0OHo0AAAKV","wgIsProbablyEditable":true,"wgRestrictionEdit":[],"wgRestrictionMove":[],"wgFlaggedRevsParams":{"tags":{}},"wgStableRevisionId":null,"wgWikiEditorEnabledModules":{"toolbar":true,"dialogs":true,"preview":false,"publish":false},"wgBetaFeaturesFeatures":[],"wgMediaViewerOnClick":true,"wgMediaViewerEnabledByDefault":true,"wgVisualEditor":{"pageLanguageCode":"en","pageLanguageDir":"ltr","usePageImages":true,"usePageDescriptions":true},"wgPreferredVariant":"en","wgMFDisplayWikibaseDescriptions":{"search":true,"nearby":true,"watchlist":true,"tagline":true},"wgRelatedArticles":null,"wgRelatedArticlesBetaFeatureEnabled":false,"wgRelatedArticlesUseCirrusSearch":true,"wgRelatedArticlesOnlyUseCirrusSearch":false,"wgULSCurrentAutonym":"English","wgNoticeProject":"wikipedia","wgCentralNoticeCookiesToDelete":[],"wgCentralNoticeCategoriesUsingLegacy":["Fundraising","fundraising"],"wgCategoryTreePageCategoryOptions":"{\"mode\":0,\"hideprefix\":20,\"showcount\":true,\"namespaces\":false}","wgWikibaseItemId":"Q7745404","wgCentralAuthMobileDomain":false,"wgVisualEditorToolbarScrollOffset":0,"wgEditSubmitButtonLabelPublish":false});mw.loader.state({"ext.globalCssJs.user.styles":"ready","ext.globalCssJs.site.styles":"ready","site.styles":"ready","noscript":"ready","user.styles":"ready","user":"ready","user.options":"loading","user.tokens":"loading","wikibase.client.init":"ready","ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.uls.interlanguage":"ready","ext.wikimediaBadges":"ready","mediawiki.legacy.shared":"ready","mediawiki.legacy.commonPrint":"ready","mediawiki.sectionAnchor":"ready","mediawiki.skinning.interface":"ready","skins.vector.styles":"ready","ext.globalCssJs.user":"ready","ext.globalCssJs.site":"ready"});mw.loader.implement("user.options@0j3lz3q",function($,jQuery,require,module){mw.user.options.set({"variant":"en"});});mw.loader.implement("user.tokens@1dqfd7l",function ( $, jQuery, require, module ) {
# mw.user.tokens.set({"editToken":"+\\","patrolToken":"+\\","watchToken":"+\\","csrfToken":"+\\"});/*@nomin*/;
#
# });mw.loader.load(["mediawiki.toc","mediawiki.action.view.postEdit","site","mediawiki.page.startup","mediawiki.user","mediawiki.hidpi","mediawiki.page.ready","mediawiki.legacy.wikibits","mediawiki.searchSuggest","ext.gadget.teahouse","ext.gadget.ReferenceTooltips","ext.gadget.watchlist-notice","ext.gadget.DRN-wizard","ext.gadget.charinsert","ext.gadget.refToolbar","ext.gadget.extra-toolbar-buttons","ext.gadget.switcher","ext.gadget.featured-articles-links","ext.centralauth.centralautologin","mmv.head","mmv.bootstrap.autostart","ext.visualEditor.desktopArticleTarget.init","ext.visualEditor.targetLoader","ext.eventLogging.subscriber","ext.wikimediaEvents","ext.navigationTiming","ext.uls.eventlogger","ext.uls.init","ext.uls.interface","ext.quicksurveys.init","ext.centralNotice.geoIP","ext.centralNotice.startUp","skins.vector.js"]);});</script>
# <link rel="stylesheet" href="/w/load.php?debug=false&amp;lang=en&amp;modules=ext.uls.interlanguage%7Cext.visualEditor.desktopArticleTarget.noscript%7Cext.wikimediaBadges%7Cmediawiki.legacy.commonPrint%2Cshared%7Cmediawiki.sectionAnchor%7Cmediawiki.skinning.interface%7Cskins.vector.styles%7Cwikibase.client.init&amp;only=styles&amp;skin=vector"/>
# <script async="" src="/w/load.php?debug=false&amp;lang=en&amp;modules=startup&amp;only=scripts&amp;skin=vector"></script>
# <meta name="ResourceLoaderDynamicStyles" content=""/>
# <link rel="stylesheet" href="/w/load.php?debug=false&amp;lang=en&amp;modules=site.styles&amp;only=styles&amp;skin=vector"/>
# <meta name="generator" content="MediaWiki 1.29.0-wmf.12"/>
# <meta name="referrer" content="origin-when-cross-origin"/>
# <meta property="og:image" content="https://upload.wikimedia.org/wikipedia/en/2/2f/Land_of_the_Dead.jpg"/>
# <link rel="alternate" href="android-app://org.wikipedia/http/en.m.wikipedia.org/wiki/The_Land_of_the_Dead"/>
# <link rel="alternate" type="application/x-wiki" title="Edit this page" href="/w/index.php?title=The_Land_of_the_Dead&amp;action=edit"/>
# <link rel="edit" title="Edit this page" href="/w/index.php?title=The_Land_of_the_Dead&amp;action=edit"/>
# <link rel="apple-touch-icon" href="/static/apple-touch/wikipedia.png"/>
# <link rel="shortcut icon" href="/static/favicon/wikipedia.ico"/>
# <link rel="search" type="application/opensearchdescription+xml" href="/w/opensearch_desc.php" title="Wikipedia (en)"/>
# <link rel="EditURI" type="application/rsd+xml" href="//en.wikipedia.org/w/api.php?action=rsd"/>
# <link rel="copyright" href="//creativecommons.org/licenses/by-sa/3.0/"/>
# <link rel="canonical" href="https://en.wikipedia.org/wiki/The_Land_of_the_Dead"/>
# <link rel="dns-prefetch" href="//login.wikimedia.org"/>
# <link rel="dns-prefetch" href="//meta.wikimedia.org" />
# </head>
# <body class="mediawiki ltr sitedir-ltr mw-hide-empty-elt ns-0 ns-subject page-The_Land_of_the_Dead rootpage-The_Land_of_the_Dead skin-vector action-view">		<div id="mw-page-base" class="noprint"></div>
# 		<div id="mw-head-base" class="noprint"></div>
# 		<div id="content" class="mw-body" role="main">
# 			<a id="top"></a>
#
# 							<div id="siteNotice"><!-- CentralNotice --></div>
# 						<div class="mw-indicators">
# </div>
# 			<h1 id="firstHeading" class="firstHeading" lang="en"><i>The Land of the Dead</i></h1>
# 									<div id="bodyContent" class="mw-body-content">
# 									<div id="siteSub">From Wikipedia, the free encyclopedia</div>
# 								<div id="contentSub"></div>
# 												<div id="jump-to-nav" class="mw-jump">
# 					Jump to:					<a href="#mw-head">navigation</a>, 					<a href="#p-search">search</a>
# 				</div>
# 				<div id="mw-content-text" lang="en" dir="ltr" class="mw-content-ltr"><table class="infobox vevent" style="width:22em">
# <tr>
# <th colspan="2" class="summary" style="text-align:center;font-size:125%;font-weight:bold;font-style: italic;">The Land of the Dead</th>
# </tr>
# <tr>
# <td colspan="2" style="text-align:center"><a href="/wiki/File:Land_of_the_Dead.jpg" class="image" title="Album cover"><img alt="Album cover" src="//upload.wikimedia.org/wikipedia/en/thumb/2/2f/Land_of_the_Dead.jpg/220px-Land_of_the_Dead.jpg" width="220" height="212" srcset="//upload.wikimedia.org/wikipedia/en/2/2f/Land_of_the_Dead.jpg 1.5x" data-file-width="318" data-file-height="306" /></a></td>
# </tr>
# <tr>
# <th colspan="2" style="text-align:center;background: #d6d6ff;"><a href="/wiki/Big_Finish_Productions" title="Big Finish Productions">Big Finish Productions</a> <a href="/wiki/Audio_drama" class="mw-redirect" title="Audio drama">audio drama</a></th>
# </tr>
# <tr>
# <th scope="row">Series</th>
# <td>'<b><a href="/wiki/Doctor_Who" title="Doctor Who">Doctor Who</a>'</b></td>
# </tr>
# <tr>
# <th scope="row">Release <abbr title="Number">no.</abbr></th>
# <td>4</td>
# </tr>
# <tr>
# <th scope="row">Featuring</th>
# <td class="attendee"><a href="/wiki/Fifth_Doctor" title="Fifth Doctor">Fifth Doctor</a><br />
# <a href="/wiki/Nyssa_(Doctor_Who)" title="Nyssa (Doctor Who)">Nyssa</a></td>
# </tr>
# <tr>
# <th scope="row">Written by</th>
# <td class="attendee"><a href="/wiki/Stephen_Cole_(writer)" title="Stephen Cole (writer)">Stephen Cole</a></td>
# </tr>
# <tr>
# <th scope="row">Directed by</th>
# <td class="attendee"><a href="/wiki/Gary_Russell" title="Gary Russell">Gary Russell</a></td>
# </tr>
# <tr>
# <th scope="row">Produced by</th>
# <td class="attendee">Gary Russell<br />
# <a href="/wiki/Jason_Haigh-Ellery" class="mw-redirect" title="Jason Haigh-Ellery">Jason Haigh-Ellery</a></td>
# </tr>
# <tr>
# <th scope="row">Executive producer(s)</th>
# <td class="attendee">Stephen Cole</td>
# </tr>
# <tr>
# <th scope="row">Production code</th>
# <td>6CA</td>
# </tr>
# <tr>
# <th scope="row">Length</th>
# <td>1 hr 54 mins</td>
# </tr>
# <tr>
# <th scope="row">Release date</th>
# <td>January 2000</td>
# </tr>
# </table>
# <p><i><b>The Land of the Dead</b></i> is a <a href="/wiki/Big_Finish_Productions" title="Big Finish Productions">Big Finish Productions</a> <a href="/wiki/List_of_Doctor_Who_audio_plays_by_Big_Finish" title="List of Doctor Who audio plays by Big Finish">audio drama</a> based on the long-running British <a href="/wiki/Science_fiction_on_television" title="Science fiction on television">science fiction television</a> series <i><a href="/wiki/Doctor_Who" title="Doctor Who">Doctor Who</a>.</i></p>
# <p></p>
# <div id="toc" class="toc">
# <div id="toctitle">
# <h2>Contents</h2>
# </div>
# <ul>
# <li class="toclevel-1 tocsection-1"><a href="#Plot"><span class="tocnumber">1</span> <span class="toctext">Plot</span></a></li>
# <li class="toclevel-1 tocsection-2"><a href="#Cast"><span class="tocnumber">2</span> <span class="toctext">Cast</span></a></li>
# <li class="toclevel-1 tocsection-3"><a href="#Notes"><span class="tocnumber">3</span> <span class="toctext">Notes</span></a></li>
# <li class="toclevel-1 tocsection-4"><a href="#External_links"><span class="tocnumber">4</span> <span class="toctext">External links</span></a>
# <ul>
# <li class="toclevel-2 tocsection-5"><a href="#Reviews"><span class="tocnumber">4.1</span> <span class="toctext">Reviews</span></a></li>
# </ul>
# </li>
# </ul>
# </div>
# <p></p>
# <h2><span class="mw-headline" id="Plot">Plot</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=The_Land_of_the_Dead&amp;action=edit&amp;section=1" title="Edit section: Plot">edit</a><span class="mw-editsection-bracket">]</span></span></h2>
# <p>Hovering just above Alaska in 1964, the TARDIS picks up some strange energy emissions of a type the Doctor and Nyssa cannot make head nor tail of. Before they can try, they are forced to dematerialise to avoid a collision with a light aircraft. But the TARDIS is apparently following a scent and takes them to the same place thirty years later. There they encounter a new kind of habitat, occupied by the obsessive Englishman Brett, Monica his interior designer and Tulung, the half-Inuit, brought up in America.</p>
# <p>Something in the snowy wastes of Alaska doesn't seem to want this new intrusion, and before long it appears as if the local spirits, revered by the Inuit, scorned by Brett, may be making some drastic attempts to erase Brett's structure and the secrets it contains from the face of the planet. If the Doctor can discover exactly what Brett has been doing, he may find a way to halt the assault, but Nyssa seems to be "in tune" with the spirits - although she doesn’t entirely like what she sees...</p>
# <h2><span class="mw-headline" id="Cast">Cast</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=The_Land_of_the_Dead&amp;action=edit&amp;section=2" title="Edit section: Cast">edit</a><span class="mw-editsection-bracket">]</span></span></h2>
# <ul>
# <li>The <a href="/wiki/Doctor_(Doctor_Who)" class="mw-redirect" title="Doctor (Doctor Who)">Doctor</a> — <a href="/wiki/Peter_Davison" title="Peter Davison">Peter Davison</a></li>
# <li><a href="/wiki/Nyssa_(Doctor_Who)" title="Nyssa (Doctor Who)">Nyssa</a> — <a href="/wiki/Sarah_Sutton" title="Sarah Sutton">Sarah Sutton</a></li>
# <li>Monica Lewis — <a href="/w/index.php?title=Lucy_Campbell_(actress)&amp;action=edit&amp;redlink=1" class="new" title="Lucy Campbell (actress) (page does not exist)">Lucy Campbell</a></li>
# <li>Supplier — <a href="/w/index.php?title=Alistair_Lock&amp;action=edit&amp;redlink=1" class="new" title="Alistair Lock (page does not exist)">Alistair Lock</a></li>
# <li>Shaun Brett — <a href="/w/index.php?title=Christopher_Scott_(actor)&amp;action=edit&amp;redlink=1" class="new" title="Christopher Scott (actor) (page does not exist)">Christopher Scott</a></li>
# <li>Tulung — <a href="/wiki/Neil_Roberts_(actor)" title="Neil Roberts (actor)">Neil Roberts</a></li>
# <li>Gaborik — <a href="/w/index.php?title=Andrew_Fettes&amp;action=edit&amp;redlink=1" class="new" title="Andrew Fettes (page does not exist)">Andrew Fettes</a></li>
# </ul>
# <h2><span class="mw-headline" id="Notes">Notes</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=The_Land_of_the_Dead&amp;action=edit&amp;section=3" title="Edit section: Notes">edit</a><span class="mw-editsection-bracket">]</span></span></h2>
# <ol>
# <li>The compact disc release includes a floor plan of the building where most of the action takes place, to aid the listener in following the action.</li>
# <li>Nyssa and the Doctor speculate that the monsters in this story were involved in the <a href="/wiki/Permian-Triassic_extinction_event" class="mw-redirect" title="Permian-Triassic extinction event">Permian-Triassic extinction event</a>, a massive reduction in Earth's biodiversity some 251.1 million years ago. They also make reference to events of the television serial <i><a href="/wiki/Earthshock" title="Earthshock">Earthshock</a></i>, which provides an explanation for the similar <a href="/wiki/Cretaceous%E2%80%93Paleogene_extinction_event" title="Cretaceous–Paleogene extinction event">Cretaceous–Paleogene extinction event</a>.</li>
# <li>Chronologically, this is the earliest audio drama in the main <i>Doctor Who</i> range to feature the Fifth Doctor, until the fourth Doctor began to do audios for Big Finish.</li>
# </ol>
# <h2><span class="mw-headline" id="External_links">External links</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=The_Land_of_the_Dead&amp;action=edit&amp;section=4" title="Edit section: External links">edit</a><span class="mw-editsection-bracket">]</span></span></h2>
# <ul>
# <li><a rel="nofollow" class="external text" href="http://www.bigfinish.com/04-Doctor-Who-The-Land-of-the-Dead">Big Finish Productions - <i>The Land of the Dead</i></a></li>
# <li><a rel="nofollow" class="external text" href="http://www.drwhoguide.com/who_bf04.htm"><i>The Land of the Dead</i></a> at the <a rel="nofollow" class="external text" href="http://www.drwhoguide.com/who.htm">Doctor Who Reference Guide</a></li>
# </ul>
# <h3><span class="mw-headline" id="Reviews">Reviews</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=The_Land_of_the_Dead&amp;action=edit&amp;section=5" title="Edit section: Reviews">edit</a><span class="mw-editsection-bracket">]</span></span></h3>
# <ul>
# <li><a rel="nofollow" class="external text" href="//web.archive.org/web/20080629192600/http://www.gallifreyone.com/review.php?id=bf-4"><i>The Land of the Dead</i></a> reviews at <a href="/wiki/Outpost_Gallifrey" title="Outpost Gallifrey">Outpost Gallifrey</a></li>
# <li><a rel="nofollow" class="external text" href="http://www.pagefillers.com/dwrg/landd.htm"><i>The Land of the Dead</i></a> reviews at <a rel="nofollow" class="external text" href="http://www.pagefillers.com/dwrg/">The Doctor Who Ratings Guide</a></li>
# </ul>
# <div style="clear:both;"></div>
# <div role="navigation" class="navbox" aria-labelledby="Fifth_Doctor_audio_dramas" style="padding:3px">
# <table class="nowraplinks collapsible autocollapse navbox-inner" style="border-spacing:0;background:transparent;color:inherit">
# <tr>
# <th scope="col" class="navbox-title" colspan="2">
# <div class="plainlinks hlist navbar mini">
# <ul>
# <li class="nv-view"><a href="/wiki/Template:Fifth_Doctor_audios" title="Template:Fifth Doctor audios"><abbr title="View this template" style=";;background:none transparent;border:none;">v</abbr></a></li>
# <li class="nv-talk"><a href="/wiki/Template_talk:Fifth_Doctor_audios" title="Template talk:Fifth Doctor audios"><abbr title="Discuss this template" style=";;background:none transparent;border:none;">t</abbr></a></li>
# <li class="nv-edit"><a class="external text" href="//en.wikipedia.org/w/index.php?title=Template:Fifth_Doctor_audios&amp;action=edit"><abbr title="Edit this template" style=";;background:none transparent;border:none;">e</abbr></a></li>
# </ul>
# </div>
# <div id="Fifth_Doctor_audio_dramas" style="font-size:114%"><a href="/wiki/Fifth_Doctor" title="Fifth Doctor">Fifth Doctor</a> audio dramas</div>
# </th>
# </tr>
# <tr style="height:2px">
# <td colspan="2"></td>
# </tr>
# <tr>
# <th scope="row" class="navbox-group">Tegan, Nyssa &amp; Adric</th>
# <td class="navbox-list navbox-odd hlist" style="text-align:left;border-left-width:2px;border-left-style:solid;width:100%;padding:0px">
# <div style="padding:0em 0.25em">
# <ul>
# <li><i><a href="/wiki/The_Darkening_Eye" title="The Darkening Eye">The Darkening Eye</a></i></li>
# <li><i><a href="/wiki/Destiny_of_the_Doctor" class="mw-redirect" title="Destiny of the Doctor">Destiny of the Doctor: Smoke and Mirrors</a></i></li>
# <li><i><a href="/wiki/Psychodrome" title="Psychodrome">Psychodrome</a></i></li>
# <li><i><a href="/wiki/Iterations_of_I" title="Iterations of I">Iterations of I</a></i></li>
# </ul>
# </div>
# </td>
# </tr>
# <tr style="height:2px">
# <td colspan="2"></td>
# </tr>
# <tr>
# <th scope="row" class="navbox-group">Nyssa</th>
# <td class="navbox-list navbox-even hlist" style="text-align:left;border-left-width:2px;border-left-style:solid;width:100%;padding:0px">
# <div style="padding:0em 0.25em">
# <ul>
# <li><i><strong class="selflink">The Land of the Dead</strong></i></li>
# <li><i><a href="/wiki/Winter_for_the_Adept" title="Winter for the Adept">Winter for the Adept</a></i></li>
# <li><i><a href="/wiki/The_Mutant_Phase" title="The Mutant Phase">The Mutant Phase</a></i></li>
# <li><i><a href="/wiki/Primeval_(audio_drama)" title="Primeval (audio drama)">Primeval</a></i></li>
# <li><i><a href="/wiki/Spare_Parts_(Doctor_Who)" title="Spare Parts (Doctor Who)">Spare Parts</a></i></li>
# <li><i><a href="/wiki/Creatures_of_Beauty" title="Creatures of Beauty">Creatures of Beauty</a></i></li>
# <li><i><a href="/wiki/The_Game_(audio_drama)" title="The Game (audio drama)">The Game</a></i></li>
# <li><i><a href="/wiki/Circular_Time" title="Circular Time">Circular Time</a></i></li>
# <li><i><a href="/wiki/Renaissance_of_the_Daleks" title="Renaissance of the Daleks">Renaissance of the Daleks</a></i></li>
# <li><i><a href="/wiki/Plague_of_the_Daleks" title="Plague of the Daleks">Plague of the Daleks</a></i></li>
# <li><i><a href="/wiki/The_Demons_of_Red_Lodge_and_Other_Stories" title="The Demons of Red Lodge and Other Stories">The Demons of Red Lodge and Other Stories</a></i></li>
# <li><i><a href="/wiki/The_Five_Companions" title="The Five Companions">The Five Companions</a></i></li>
# <li><i><a href="/wiki/1001_Nights_(Doctor_Who_audio)" title="1001 Nights (Doctor Who audio)">1001 Nights</a></i></li>
# <li><i><a href="/wiki/The_Light_at_the_End_(Doctor_Who_audio)" title="The Light at the End (Doctor Who audio)">The Light at the End</a></i></li>
# <li><i><a href="/wiki/Moonflesh" title="Moonflesh">Moonflesh</a></i></li>
# </ul>
# </div>
# </td>
# </tr>
# <tr style="height:2px">
# <td colspan="2"></td>
# </tr>
# <tr>
# <th scope="row" class="navbox-group">Nyssa &amp; Brewster</th>
# <td class="navbox-list navbox-odd hlist" style="text-align:left;border-left-width:2px;border-left-style:solid;width:100%;padding:0px">
# <div style="padding:0em 0.25em">
# <ul>
# <li><i><a href="/wiki/The_Haunting_of_Thomas_Brewster" title="The Haunting of Thomas Brewster">The Haunting of Thomas Brewster</a></i></li>
# <li><i><a href="/wiki/The_Boy_That_Time_Forgot" title="The Boy That Time Forgot">The Boy That Time Forgot</a></i></li>
# <li><i><a href="/wiki/Time_Reef" title="Time Reef">Time Reef</a></i></li>
# <li><i><a href="/wiki/A_Perfect_World_(audio_drama)" title="A Perfect World (audio drama)">A Perfect World</a></i></li>
# </ul>
# </div>
# </td>
# </tr>
# <tr style="height:2px">
# <td colspan="2"></td>
# </tr>
# <tr>
# <th scope="row" class="navbox-group">Nyssa &amp; Tegan</th>
# <td class="navbox-list navbox-even hlist" style="text-align:left;border-left-width:2px;border-left-style:solid;width:100%;padding:0px">
# <div style="padding:0em 0.25em">
# <ul>
# <li><i><a href="/wiki/The_Elite_(Doctor_Who_audio)" title="The Elite (Doctor Who audio)">The Elite</a></i></li>
# <li><i><a href="/wiki/Hexagora" title="Hexagora">Hexagora</a></i></li>
# <li><i><a href="/wiki/The_Children_of_Seth" title="The Children of Seth">The Children of Seth</a></i></li>
# </ul>
# </div>
# </td>
# </tr>
# <tr style="height:2px">
# <td colspan="2"></td>
# </tr>
# <tr>
# <th scope="row" class="navbox-group">Nyssa, Tegan &amp; Turlough</th>
# <td class="navbox-list navbox-odd hlist" style="text-align:left;border-left-width:2px;border-left-style:solid;width:100%;padding:0px">
# <div style="padding:0em 0.25em">
# <ul>
# <li><i><a href="/wiki/Cobwebs_(audio_drama)" title="Cobwebs (audio drama)">Cobwebs</a></i></li>
# <li><i><a href="/wiki/The_Whispering_Forest" title="The Whispering Forest">The Whispering Forest</a></i></li>
# <li><i><a href="/wiki/The_Cradle_of_the_Snake" title="The Cradle of the Snake">The Cradle of the Snake</a></i></li>
# <li><i><a href="/wiki/Heroes_of_Sontar" title="Heroes of Sontar">Heroes of Sontar</a></i></li>
# <li><i><a href="/wiki/Kiss_of_Death_(Doctor_Who_audio)" title="Kiss of Death (Doctor Who audio)">Kiss of Death</a></i></li>
# <li><i><a href="/wiki/Rat_Trap_(Doctor_Who_audio)" title="Rat Trap (Doctor Who audio)">Rat Trap</a></i></li>
# <li><i><a href="/wiki/The_Emerald_Tiger" title="The Emerald Tiger">The Emerald Tiger</a></i></li>
# <li><i><a href="/wiki/The_Jupiter_Conjunction" title="The Jupiter Conjunction">The Jupiter Conjunction</a></i></li>
# <li><i><a href="/wiki/The_Butcher_of_Brisbane" title="The Butcher of Brisbane">The Butcher of Brisbane</a></i></li>
# <li><i><a href="/wiki/The_Entropy_Plague" title="The Entropy Plague">The Entropy Plague</a></i></li>
# </ul>
# </div>
# </td>
# </tr>
# <tr style="height:2px">
# <td colspan="2"></td>
# </tr>
# <tr>
# <th scope="row" class="navbox-group">Tegan &amp; Turlough</th>
# <td class="navbox-list navbox-even hlist" style="text-align:left;border-left-width:2px;border-left-style:solid;width:100%;padding:0px">
# <div style="padding:0em 0.25em">
# <ul>
# <li><i><a href="/wiki/The_Sirens_of_Time" title="The Sirens of Time">The Sirens of Time</a></i></li>
# <li><i><a href="/wiki/Excelis_Dawns" title="Excelis Dawns">Excelis Dawns</a></i></li>
# <li><i><a href="/wiki/Ringpullworld" title="Ringpullworld">Ringpullworld</a></i></li>
# <li><i><a href="/wiki/Freakshow_(audio_drama)" title="Freakshow (audio drama)">Freakshow</a></i></li>
# </ul>
# </div>
# </td>
# </tr>
# <tr style="height:2px">
# <td colspan="2"></td>
# </tr>
# <tr>
# <th scope="row" class="navbox-group">Turlough</th>
# <td class="navbox-list navbox-odd hlist" style="text-align:left;border-left-width:2px;border-left-style:solid;width:100%;padding:0px">
# <div style="padding:0em 0.25em">
# <ul>
# <li><i><a href="/wiki/Phantasmagoria_(audio_drama)" title="Phantasmagoria (audio drama)">Phantasmagoria</a></i></li>
# <li><i><a href="/wiki/Loups-Garoux" title="Loups-Garoux">Loups-Garoux</a></i></li>
# <li><i><a href="/wiki/Singularity_(audio_drama)" title="Singularity (audio drama)">Singularity</a></i></li>
# </ul>
# </div>
# </td>
# </tr>
# <tr style="height:2px">
# <td colspan="2"></td>
# </tr>
# <tr>
# <th scope="row" class="navbox-group">Peri</th>
# <td class="navbox-list navbox-even hlist" style="text-align:left;border-left-width:2px;border-left-style:solid;width:100%;padding:0px">
# <div style="padding:0em 0.25em">
# <ul>
# <li><i><a href="/wiki/Red_Dawn_(audio_drama)" title="Red Dawn (audio drama)">Red Dawn</a></i></li>
# <li><i><a href="/wiki/Exotron_%26_Urban_Myths" title="Exotron &amp; Urban Myths">Exotron &amp; Urban Myths</a></i></li>
# <li><i><a href="/wiki/Peri_and_the_Piscon_Paradox" title="Peri and the Piscon Paradox">Peri and the Piscon Paradox</a></i></li>
# </ul>
# </div>
# </td>
# </tr>
# <tr style="height:2px">
# <td colspan="2"></td>
# </tr>
# <tr>
# <th scope="row" class="navbox-group">Peri &amp; Erimem</th>
# <td class="navbox-list navbox-odd hlist" style="text-align:left;border-left-width:2px;border-left-style:solid;width:100%;padding:0px">
# <div style="padding:0em 0.25em">
# <ul>
# <li><i><a href="/wiki/The_Eye_of_the_Scorpion" title="The Eye of the Scorpion">The Eye of the Scorpion</a></i></li>
# <li><i><a href="/wiki/The_Church_and_the_Crown" title="The Church and the Crown">The Church and the Crown</a></i></li>
# <li><i><a href="/wiki/No_Place_Like_Home_(audio_drama)" title="No Place Like Home (audio drama)">No Place Like Home</a></i></li>
# <li><i><a href="/wiki/Nekromanteia_(audio_drama)" title="Nekromanteia (audio drama)">Nekromanteia</a></i></li>
# <li><i><a href="/wiki/The_Axis_of_Insanity" title="The Axis of Insanity">The Axis of Insanity</a></i></li>
# <li><i><a href="/wiki/The_Roof_of_the_World" title="The Roof of the World">The Roof of the World</a></i></li>
# <li><i><a href="/wiki/Three%27s_a_Crowd_(radio)" title="Three's a Crowd (radio)">Three's a Crowd</a></i></li>
# <li><i><a href="/wiki/The_Council_of_Nicaea_(audio_drama)" title="The Council of Nicaea (audio drama)">The Council of Nicaea</a></i></li>
# <li><i><a href="/wiki/The_Kingmaker" title="The Kingmaker">The Kingmaker</a></i></li>
# <li><i><a href="/wiki/Son_of_the_Dragon_(Doctor_Who_audio)" title="Son of the Dragon (Doctor Who audio)">Son of the Dragon</a></i></li>
# <li><i><a href="/wiki/The_Mind%27s_Eye_%26_Mission_of_the_Viyrans" title="The Mind's Eye &amp; Mission of the Viyrans">The Mind's Eye &amp; Mission of the Viyrans</a></i></li>
# <li><i><a href="/wiki/The_Bride_of_Peladon" title="The Bride of Peladon">The Bride of Peladon</a></i></li>
# </ul>
# </div>
# </td>
# </tr>
# <tr style="height:2px">
# <td colspan="2"></td>
# </tr>
# <tr>
# <th scope="row" class="navbox-group">Amy</th>
# <td class="navbox-list navbox-even hlist" style="text-align:left;border-left-width:2px;border-left-style:solid;width:100%;padding:0px">
# <div style="padding:0em 0.25em">
# <ul>
# <li><i><a href="/wiki/The_Judgement_of_Isskar" title="The Judgement of Isskar">The Judgement of Isskar</a></i></li>
# <li><i><a href="/wiki/The_Destroyer_of_Delights" title="The Destroyer of Delights">The Destroyer of Delights</a></i></li>
# <li><i><a href="/wiki/The_Chaos_Pool" title="The Chaos Pool">The Chaos Pool</a></i></li>
# </ul>
# </div>
# </td>
# </tr>
# <tr style="height:2px">
# <td colspan="2"></td>
# </tr>
# <tr>
# <th scope="row" class="navbox-group">Other</th>
# <td class="navbox-list navbox-odd hlist" style="text-align:left;border-left-width:2px;border-left-style:solid;width:100%;padding:0px">
# <div style="padding:0em 0.25em">
# <ul>
# <li><i><a href="/wiki/Zagreus_(audio_drama)" title="Zagreus (audio drama)">Zagreus</a></i></li>
# <li><i><a href="/wiki/Omega_(audio_drama)" title="Omega (audio drama)">Omega</a></i></li>
# <li><i><a href="/wiki/The_Gathering_(audio_drama)" title="The Gathering (audio drama)">The Gathering</a></i></li>
# <li><i><a href="/wiki/Cuddlesome" title="Cuddlesome">Cuddlesome</a></i></li>
# <li><i><a href="/wiki/The_Four_Doctors" title="The Four Doctors">The Four Doctors</a></i></li>
# <li><i><a href="/wiki/The_Burning_Prince" title="The Burning Prince">The Burning Prince</a></i></li>
# </ul>
# </div>
# </td>
# </tr>
# </table>
# </div>
#
#
# <!--
# NewPP limit report
# Parsed by mw1290
# Cached time: 20170221104802
# Cache expiry: 2592000
# Dynamic content: false
# CPU time usage: 0.064 seconds
# Real time usage: 0.087 seconds
# Preprocessor visited node count: 377/1000000
# Preprocessor generated node count: 0/1500000
# Post‐expand include size: 24855/2097152 bytes
# Template argument size: 411/2097152 bytes
# Highest expansion depth: 6/40
# Expensive parser function count: 0/500
# Lua time usage: 0.019/10.000 seconds
# Lua memory usage: 1.03 MB/50 MB
# -->
# <!--
# Transclusion expansion time report (%,ms,calls,template)
# 100.00%   53.214      1 -total
#  65.22%   34.706      1 Template:Infobox_audio_drama
#  60.94%   32.428      1 Template:Infobox
#  23.11%   12.298      1 Template:Fifth_Doctor_audios
#  16.91%    9.001      1 Template:Navbox
#   3.04%    1.618      1 Template:OG_review
#   2.85%    1.518      1 Template:DWRG
#   2.58%    1.375      1 Template:Doctor_Who_RG
#   2.05%    1.092      1 Template:Clear
# -->
#
# <!-- Saved in parser cache with key enwiki:pcache:idhash:1633029-0!*!0!!en!4!* and timestamp 20170221104802 and revision id 754928354
#  -->
# <noscript><img src="//en.wikipedia.org/wiki/Special:CentralAutoLogin/start?type=1x1" alt="" title="" width="1" height="1" style="border: none; position: absolute;" /></noscript></div>					<div class="printfooter">
# 						Retrieved from "<a dir="ltr" href="https://en.wikipedia.org/w/index.php?title=The_Land_of_the_Dead&amp;oldid=754928354">https://en.wikipedia.org/w/index.php?title=The_Land_of_the_Dead&amp;oldid=754928354</a>"					</div>
# 				<div id="catlinks" class="catlinks" data-mw="interface"><div id="mw-normal-catlinks" class="mw-normal-catlinks"><a href="/wiki/Help:Category" title="Help:Category">Categories</a>: <ul><li><a href="/wiki/Category:Fifth_Doctor_audio_plays" title="Category:Fifth Doctor audio plays">Fifth Doctor audio plays</a></li><li><a href="/wiki/Category:2000_audio_plays" title="Category:2000 audio plays">2000 audio plays</a></li></ul></div></div>				<div class="visualClear"></div>
# 							</div>
# 		</div>
# 		<div id="mw-navigation">
# 			<h2>Navigation menu</h2>
#
# 			<div id="mw-head">
# 									<div id="p-personal" role="navigation" class="" aria-labelledby="p-personal-label">
# 						<h3 id="p-personal-label">Personal tools</h3>
# 						<ul>
# 							<li id="pt-anonuserpage">Not logged in</li><li id="pt-anontalk"><a href="/wiki/Special:MyTalk" title="Discussion about edits from this IP address [n]" accesskey="n">Talk</a></li><li id="pt-anoncontribs"><a href="/wiki/Special:MyContributions" title="A list of edits made from this IP address [y]" accesskey="y">Contributions</a></li><li id="pt-createaccount"><a href="/w/index.php?title=Special:CreateAccount&amp;returnto=The+Land+of+the+Dead" title="You are encouraged to create an account and log in; however, it is not mandatory">Create account</a></li><li id="pt-login"><a href="/w/index.php?title=Special:UserLogin&amp;returnto=The+Land+of+the+Dead" title="You're encouraged to log in; however, it's not mandatory. [o]" accesskey="o">Log in</a></li>						</ul>
# 					</div>
# 									<div id="left-navigation">
# 										<div id="p-namespaces" role="navigation" class="vectorTabs" aria-labelledby="p-namespaces-label">
# 						<h3 id="p-namespaces-label">Namespaces</h3>
# 						<ul>
# 															<li  id="ca-nstab-main" class="selected"><span><a href="/wiki/The_Land_of_the_Dead"  title="View the content page [c]" accesskey="c">Article</a></span></li>
# 															<li  id="ca-talk"><span><a href="/wiki/Talk:The_Land_of_the_Dead"  title="Discussion about the content page [t]" accesskey="t" rel="discussion">Talk</a></span></li>
# 													</ul>
# 					</div>
# 										<div id="p-variants" role="navigation" class="vectorMenu emptyPortlet" aria-labelledby="p-variants-label">
# 												<h3 id="p-variants-label">
# 							<span>Variants</span><a href="#"></a>
# 						</h3>
#
# 						<div class="menu">
# 							<ul>
# 															</ul>
# 						</div>
# 					</div>
# 									</div>
# 				<div id="right-navigation">
# 										<div id="p-views" role="navigation" class="vectorTabs" aria-labelledby="p-views-label">
# 						<h3 id="p-views-label">Views</h3>
# 						<ul>
# 															<li id="ca-view" class="selected"><span><a href="/wiki/The_Land_of_the_Dead" >Read</a></span></li>
# 															<li id="ca-edit"><span><a href="/w/index.php?title=The_Land_of_the_Dead&amp;action=edit"  title="Edit this page [e]" accesskey="e">Edit</a></span></li>
# 															<li id="ca-history" class="collapsible"><span><a href="/w/index.php?title=The_Land_of_the_Dead&amp;action=history"  title="Past revisions of this page [h]" accesskey="h">View history</a></span></li>
# 													</ul>
# 					</div>
# 										<div id="p-cactions" role="navigation" class="vectorMenu emptyPortlet" aria-labelledby="p-cactions-label">
# 						<h3 id="p-cactions-label"><span>More</span><a href="#"></a></h3>
#
# 						<div class="menu">
# 							<ul>
# 															</ul>
# 						</div>
# 					</div>
# 										<div id="p-search" role="search">
# 						<h3>
# 							<label for="searchInput">Search</label>
# 						</h3>
#
# 						<form action="/w/index.php" id="searchform">
# 							<div id="simpleSearch">
# 							<input type="search" name="search" placeholder="Search Wikipedia" title="Search Wikipedia [f]" accesskey="f" id="searchInput"/><input type="hidden" value="Special:Search" name="title"/><input type="submit" name="fulltext" value="Search" title="Search Wikipedia for this text" id="mw-searchButton" class="searchButton mw-fallbackSearchButton"/><input type="submit" name="go" value="Go" title="Go to a page with this exact name if it exists" id="searchButton" class="searchButton"/>							</div>
# 						</form>
# 					</div>
# 									</div>
# 			</div>
# 			<div id="mw-panel">
# 				<div id="p-logo" role="banner"><a class="mw-wiki-logo" href="/wiki/Main_Page"  title="Visit the main page"></a></div>
# 						<div class="portal" role="navigation" id='p-navigation' aria-labelledby='p-navigation-label'>
# 			<h3 id='p-navigation-label'>Navigation</h3>
#
# 			<div class="body">
# 									<ul>
# 						<li id="n-mainpage-description"><a href="/wiki/Main_Page" title="Visit the main page [z]" accesskey="z">Main page</a></li><li id="n-contents"><a href="/wiki/Portal:Contents" title="Guides to browsing Wikipedia">Contents</a></li><li id="n-featuredcontent"><a href="/wiki/Portal:Featured_content" title="Featured content – the best of Wikipedia">Featured content</a></li><li id="n-currentevents"><a href="/wiki/Portal:Current_events" title="Find background information on current events">Current events</a></li><li id="n-randompage"><a href="/wiki/Special:Random" title="Load a random article [x]" accesskey="x">Random article</a></li><li id="n-sitesupport"><a href="https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&amp;utm_medium=sidebar&amp;utm_campaign=C13_en.wikipedia.org&amp;uselang=en" title="Support us">Donate to Wikipedia</a></li><li id="n-shoplink"><a href="//shop.wikimedia.org" title="Visit the Wikipedia store">Wikipedia store</a></li>					</ul>
# 							</div>
# 		</div>
# 			<div class="portal" role="navigation" id='p-interaction' aria-labelledby='p-interaction-label'>
# 			<h3 id='p-interaction-label'>Interaction</h3>
#
# 			<div class="body">
# 									<ul>
# 						<li id="n-help"><a href="/wiki/Help:Contents" title="Guidance on how to use and edit Wikipedia">Help</a></li><li id="n-aboutsite"><a href="/wiki/Wikipedia:About" title="Find out about Wikipedia">About Wikipedia</a></li><li id="n-portal"><a href="/wiki/Wikipedia:Community_portal" title="About the project, what you can do, where to find things">Community portal</a></li><li id="n-recentchanges"><a href="/wiki/Special:RecentChanges" title="A list of recent changes in the wiki [r]" accesskey="r">Recent changes</a></li><li id="n-contactpage"><a href="//en.wikipedia.org/wiki/Wikipedia:Contact_us" title="How to contact Wikipedia">Contact page</a></li>					</ul>
# 							</div>
# 		</div>
# 			<div class="portal" role="navigation" id='p-tb' aria-labelledby='p-tb-label'>
# 			<h3 id='p-tb-label'>Tools</h3>
#
# 			<div class="body">
# 									<ul>
# 						<li id="t-whatlinkshere"><a href="/wiki/Special:WhatLinksHere/The_Land_of_the_Dead" title="List of all English Wikipedia pages containing links to this page [j]" accesskey="j">What links here</a></li><li id="t-recentchangeslinked"><a href="/wiki/Special:RecentChangesLinked/The_Land_of_the_Dead" rel="nofollow" title="Recent changes in pages linked from this page [k]" accesskey="k">Related changes</a></li><li id="t-upload"><a href="/wiki/Wikipedia:File_Upload_Wizard" title="Upload files [u]" accesskey="u">Upload file</a></li><li id="t-specialpages"><a href="/wiki/Special:SpecialPages" title="A list of all special pages [q]" accesskey="q">Special pages</a></li><li id="t-permalink"><a href="/w/index.php?title=The_Land_of_the_Dead&amp;oldid=754928354" title="Permanent link to this revision of the page">Permanent link</a></li><li id="t-info"><a href="/w/index.php?title=The_Land_of_the_Dead&amp;action=info" title="More information about this page">Page information</a></li><li id="t-wikibase"><a href="https://www.wikidata.org/wiki/Q7745404" title="Link to connected data repository item [g]" accesskey="g">Wikidata item</a></li><li id="t-cite"><a href="/w/index.php?title=Special:CiteThisPage&amp;page=The_Land_of_the_Dead&amp;id=754928354" title="Information on how to cite this page">Cite this page</a></li>					</ul>
# 							</div>
# 		</div>
# 			<div class="portal" role="navigation" id='p-coll-print_export' aria-labelledby='p-coll-print_export-label'>
# 			<h3 id='p-coll-print_export-label'>Print/export</h3>
#
# 			<div class="body">
# 									<ul>
# 						<li id="coll-create_a_book"><a href="/w/index.php?title=Special:Book&amp;bookcmd=book_creator&amp;referer=The+Land+of+the+Dead">Create a book</a></li><li id="coll-download-as-rdf2latex"><a href="/w/index.php?title=Special:Book&amp;bookcmd=render_article&amp;arttitle=The+Land+of+the+Dead&amp;returnto=The+Land+of+the+Dead&amp;oldid=754928354&amp;writer=rdf2latex">Download as PDF</a></li><li id="t-print"><a href="/w/index.php?title=The_Land_of_the_Dead&amp;printable=yes" title="Printable version of this page [p]" accesskey="p">Printable version</a></li>					</ul>
# 							</div>
# 		</div>
# 			<div class="portal" role="navigation" id='p-lang' aria-labelledby='p-lang-label'>
# 			<h3 id='p-lang-label'>Languages</h3>
#
# 			<div class="body">
# 									<ul>
# 											</ul>
# 				<div class='after-portlet after-portlet-lang'><span class="wb-langlinks-add wb-langlinks-link"><a href="https://www.wikidata.org/wiki/Q7745404#sitelinks-wikipedia" title="Add interlanguage links" class="wbc-editpage">Add links</a></span></div>			</div>
# 		</div>
# 				</div>
# 		</div>
# 		<div id="footer" role="contentinfo">
# 							<ul id="footer-info">
# 											<li id="footer-info-lastmod"> This page was last modified on 15 December 2016, at 07:58.</li>
# 											<li id="footer-info-copyright">Text is available under the <a rel="license" href="//en.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License">Creative Commons Attribution-ShareAlike License</a><a rel="license" href="//creativecommons.org/licenses/by-sa/3.0/" style="display:none;"></a>;
# additional terms may apply.  By using this site, you agree to the <a href="//wikimediafoundation.org/wiki/Terms_of_Use">Terms of Use</a> and <a href="//wikimediafoundation.org/wiki/Privacy_policy">Privacy Policy</a>. Wikipedia® is a registered trademark of the <a href="//www.wikimediafoundation.org/">Wikimedia Foundation, Inc.</a>, a non-profit organization.</li>
# 									</ul>
# 							<ul id="footer-places">
# 											<li id="footer-places-privacy"><a href="https://wikimediafoundation.org/wiki/Privacy_policy" class="extiw" title="wmf:Privacy policy">Privacy policy</a></li>
# 											<li id="footer-places-about"><a href="/wiki/Wikipedia:About" title="Wikipedia:About">About Wikipedia</a></li>
# 											<li id="footer-places-disclaimer"><a href="/wiki/Wikipedia:General_disclaimer" title="Wikipedia:General disclaimer">Disclaimers</a></li>
# 											<li id="footer-places-contact"><a href="//en.wikipedia.org/wiki/Wikipedia:Contact_us">Contact Wikipedia</a></li>
# 											<li id="footer-places-developers"><a href="https://www.mediawiki.org/wiki/Special:MyLanguage/How_to_contribute">Developers</a></li>
# 											<li id="footer-places-cookiestatement"><a href="https://wikimediafoundation.org/wiki/Cookie_statement">Cookie statement</a></li>
# 											<li id="footer-places-mobileview"><a href="//en.m.wikipedia.org/w/index.php?title=The_Land_of_the_Dead&amp;mobileaction=toggle_view_mobile" class="noprint stopMobileRedirectToggle">Mobile view</a></li>
# 									</ul>
# 										<ul id="footer-icons" class="noprint">
# 											<li id="footer-copyrightico">
# 							<a href="https://wikimediafoundation.org/"><img src="/static/images/wikimedia-button.png" srcset="/static/images/wikimedia-button-1.5x.png 1.5x, /static/images/wikimedia-button-2x.png 2x" width="88" height="31" alt="Wikimedia Foundation"/></a>						</li>
# 											<li id="footer-poweredbyico">
# 							<a href="//www.mediawiki.org/"><img src="/static/images/poweredby_mediawiki_88x31.png" alt="Powered by MediaWiki" srcset="/static/images/poweredby_mediawiki_132x47.png 1.5x, /static/images/poweredby_mediawiki_176x62.png 2x" width="88" height="31"/></a>						</li>
# 									</ul>
# 						<div style="clear:both"></div>
# 		</div>
# 		<script>(window.RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgPageParseReport":{"limitreport":{"cputime":"0.064","walltime":"0.087","ppvisitednodes":{"value":377,"limit":1000000},"ppgeneratednodes":{"value":0,"limit":1500000},"postexpandincludesize":{"value":24855,"limit":2097152},"templateargumentsize":{"value":411,"limit":2097152},"expansiondepth":{"value":6,"limit":40},"expensivefunctioncount":{"value":0,"limit":500},"entityaccesscount":{"value":0,"limit":400},"timingprofile":["100.00%   53.214      1 -total"," 65.22%   34.706      1 Template:Infobox_audio_drama"," 60.94%   32.428      1 Template:Infobox"," 23.11%   12.298      1 Template:Fifth_Doctor_audios"," 16.91%    9.001      1 Template:Navbox","  3.04%    1.618      1 Template:OG_review","  2.85%    1.518      1 Template:DWRG","  2.58%    1.375      1 Template:Doctor_Who_RG","  2.05%    1.092      1 Template:Clear"]},"scribunto":{"limitreport-timeusage":{"value":"0.019","limit":"10.000"},"limitreport-memusage":{"value":1080709,"limit":52428800}},"cachereport":{"origin":"mw1290","timestamp":"20170221104802","ttl":2592000,"transientcontent":false}}});});</script><script>(window.RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgBackendResponseTime":58,"wgHostname":"mw1176"});});</script>
# 	</body>
# </html>

# %% [markdown]
# We notice that the content is inside the div tag with the "content" id.

# %% [markdown]
# ## Read in the data

# %% [markdown]
# Now that we know the file structure, and the structure of a single file, we can read in all of the files. This will get us started in our explorations.

# %%
import time

def read_data(filename):
    with open(filename) as f:
        data = f.read()
    return data

start = time.time()
filenames = ["wiki/{}".format(f) for f in os.listdir("wiki")]

content = list()
for filename in filenames : 
    content.append(read_data(filename))

end = time.time()
print(end - start)
# Out:
# 0.1779499053955078

# %% [markdown]
# As this task is I/O bound, we can use threads to help us read in the data more quickly.

# %%
import concurrent.futures
import time

pool = concurrent.futures.ThreadPoolExecutor(max_workers=4)

def read_data(filename):
    with open(filename) as f:
        data = f.read()
    return data

start = time.time()
filenames = ["wiki/{}".format(f) for f in os.listdir("wiki")]
content = pool.map(read_data, filenames)
content = list(content)

end = time.time()
print(end - start)
# Out:
# 0.4769864082336426

# %% [markdown]
# In this case, it seems that threading doesn't help to improve the performance. It may be because although files are opened, most of the task is offset by the overhead of creating new threads

# %%
articles = [f.replace(".html", "").replace("wiki/", "") for f in filenames]

# %% [markdown]
# ## Remove Extraneous Markup

# %% [markdown]
# Now that we have read in the data files, we can remove the extraneous markup that is outside the div#content tag that most of the content seems to be inside.
# We can use the [BeautifulSoup](https://www.crummy.com/software/BeautifulSoup/) package for that. BeautifulSoup enables us to extract all of the content inside a specific tag.

# %%
from bs4 import BeautifulSoup

def parse_html(html):
    soup = BeautifulSoup(html, "html.parser")
    content = str(soup.find_all("div", id="content")[0])
    return content

start = time.time()

parsed = list()
for cont in content :
    parsed.append(parse_html(cont))
    
end = time.time()
print(end-start)
# Out:
# 50.30543303489685

# %% [markdown]
# This operation is more CPU intensive than before. Let's try using a process pool to see if the speed improves. Let's attempt with different numbers of workers and see how that affects performance.

# %%
from bs4 import BeautifulSoup

def parsed_html(html):
    soup = BeautifulSoup(html, "html.parser")
    content = str(soup.find_all("div", id="content")[0])
    return content

for workers in range(1,6):
    parsed = None
    start = time.time()
    pool = concurrent.futures.ProcessPoolExecutor(max_workers=workers)
    parsed = pool.map(parsed_html, content)
    parsed = list(parsed)
    end = time.time()
    print("Time elapsed for {} workers : {}".format(workers, end-start))
# Out:
# Time elapsed for 1 workers : 49.68454551696777
# Time elapsed for 2 workers : 35.298086166381836
# Time elapsed for 3 workers : 34.58976650238037
# Time elapsed for 4 workers : 35.049715995788574
# Time elapsed for 5 workers : 35.6042754650116

# %% [markdown]
# It seems that 2 workers are the best for our computer, which is surprising as we have 4 CPUs. It depends on what other computations the CPU is doing at the moment. We note that using 1 worker is 1 second longer than processing without the threading strategy. It is logic as mapping the pool is an additional computation.

# %% [markdown]
# ## Finding Common Tags

# %% [markdown]
# Now that we've extracted the main part of each page let's count up how many times each tag occurs. This will give us clues about how Wikipedia pages are typically structured. For example, if there are a lot of "a" tags on each page, we know that Wikipedia articles tend to be very connected to other articles or pages. On the other hand, a lot of div tags will tell us that Wikipedia pages tend to have a nested structure with many page elements.
# We'll directly

# %%
from bs4 import BeautifulSoup
import pandas as pd

def count_tags(html):
    soup = BeautifulSoup(html, 'html.parser')
    tags = {}
    for tag in soup.find_all():
        if tag.name not in tags:
            tags[tag.name] = 0
        tags[tag.name] += 1
    return tags

start = time.time()
pool = concurrent.futures.ProcessPoolExecutor(max_workers=3)
tags = pool.map(count_tags, parsed)

tag_counts = {}
for tag in tags:
    for k,v in tag.items():
        if k not in tag_counts:
            tag_counts[k] = 0
        tag_counts[k] += v
end = time.time()

print(end - start)
# Out:
# 19.87275218963623

# %%
sorted(tag_counts.items(), key=lambda x: (-x[1], x[0]))
# Out:
# [('a', 161065),
#  ('li', 85779),
#  ('span', 67350),
#  ('td', 57673),
#  ('div', 28581),
#  ('tr', 27300),
#  ('i', 18246),
#  ('th', 14472),
#  ('b', 14455),
#  ('sup', 11157),
#  ('ul', 10972),
#  ('p', 7998),
#  ('img', 6701),
#  ('br', 4986),
#  ('h2', 4045),
#  ('table', 4010),
#  ('abbr', 3665),
#  ('cite', 3563),
#  ('small', 3272),
#  ('dd', 1376),
#  ('h1', 999),
#  ('noscript', 999),
#  ('ol', 858),
#  ('h3', 777),
#  ('strong', 599),
#  ('dl', 457),
#  ('dt', 334),
#  ('caption', 200),
#  ('sub', 151),
#  ('h4', 117),
#  ('code', 108),
#  ('wbr', 85),
#  ('q', 76),
#  ('big', 75),
#  ('center', 64),
#  ('blockquote', 58),
#  ('hr', 51),
#  ('u', 51),
#  ('font', 40),
#  ('area', 39),
#  ('rp', 32),
#  ('rb', 16),
#  ('rt', 16),
#  ('ruby', 16),
#  ('s', 10),
#  ('bdi', 4),
#  ('h5', 4),
#  ('annotation', 2),
#  ('audio', 2),
#  ('del', 2),
#  ('map', 2),
#  ('math', 2),
#  ('mo', 2),
#  ('mrow', 2),
#  ('mstyle', 2),
#  ('samp', 2),
#  ('semantics', 2),
#  ('source', 2),
#  ('h6', 1),
#  ('pre', 1)]

# %% [markdown]
# Based on our findings, it looks like there are quite a few td, a, li, and span tags. This indicates that articles tend to have lots of links, along with lists and tables. Links are the most numerous tag, which indicates how interconnected articles on Wikipedia are.

# %% [markdown]
# ## Finding Common Words

# %% [markdown]
# Let's consider only words with more than 5 letters.

# %%
from bs4 import BeautifulSoup
from collections import Counter
import re

def count_words(html):
    soup = BeautifulSoup(html, 'html.parser')
    words = {}
    text = soup.get_text()
    text = re.sub("\W+", " ", text.lower())
    words = text.split(" ")
    words = [w for w in words if len(w) >= 5]
    return Counter(words).most_common(1500)

start = time.time()
pool = concurrent.futures.ProcessPoolExecutor(max_workers=3)
words = pool.map(count_words, parsed)
words = list(words)

word_counts = {}
for wc in words:
    for word, count in wc:
        if word not in word_counts:
            word_counts[word] = 0
        word_counts[word] += 1
end = time.time()

print(end - start)
word_counts
# Out:
# 20.31219458580017
# {'dewulf': 1,
#  'propaganda': 8,
#  'watson': 14,
#  'lungsod': 1,
#  'andijani': 1,
#  'tabimorelin': 1,
#  'mulholland': 1,
#  'flori': 1,
#  'adrain': 1,
#  'middle': 61,
#  'garnered': 3,
#  'pearsall': 1,
#  'furthermore': 13,
#  'démocratie': 1,
#  'pekel': 1,
#  'myriad': 3,
#  '705th': 1,
#  'teamminnesota': 1,
#  'shelapur': 1,
#  'hamlets': 1,
#  'freshwater': 7,
#  'hangenbieten': 1,
#  'slopes': 6,
#  'recognize': 5,
#  'lagoa': 1,
#  'eaten': 2,
#  'χαρβάτι': 1,
#  'mayocounty': 1,
#  'snowboarder': 1,
#  'sirdar': 1,
#  'constructive': 1,
#  'moralphilosophie': 1,
#  'idstedt': 1,
#  'brushing': 1,
#  '47273': 1,
#  'aldopentoses': 1,
#  'cisticolas': 1,
#  'cottonfields': 1,
#  'castilblanco': 1,
#  'bellas': 1,
#  'collapse': 9,
#  '1200mm': 1,
#  'kaduna': 1,
#  'phalanx': 2,
#  'bourneville': 1,
#  'vasculaire': 1,
#  'gower': 4,
#  'mostly': 33,
#  'caddo': 1,
#  'molecular': 20,
#  'toulon': 5,
#  'teacher': 22,
#  'pikimachay': 1,
#  'correct': 31,
#  'gentile': 1,
#  'michiko': 1,
#  'colima': 1,
#  'smothers': 1,
#  'metiseducation': 1,
#  'jetterswiller': 1,
#  'canberra': 7,
#  '76027': 1,
#  'berru': 2,
#  'laikha': 1,
#  'kumantsov': 1,
#  'waites': 1,
#  'dikson': 1,
#  'cccii': 1,
#  'songsbillboard': 1,
#  'listićima': 1,
#  'result': 79,
#  'appurtenances': 1,
#  'rejang': 1,
#  'motyei': 1,
#  'rosny': 1,
#  'droylsden': 1,
#  'hornos': 1,
#  'finished': 40,
#  'rubinstein': 1,
#  'foiled': 1,
#  'proglucagon': 1,
#  'ingénieurs': 1,
#  'borin': 1,
#  'referendumsreferendums': 1,
#  'enfers': 1,
#  'eoliene': 1,
#  '32194': 1,
#  'graphic': 12,
#  '26_monson_academy': 1,
#  'filmsamerican': 10,
#  'farnell': 1,
#  'silla': 2,
#  'osborn': 1,
#  'colossus': 1,
#  'squadron': 8,
#  'naxos': 2,
#  'isothermic': 1,
#  'lidsky': 1,
#  'indiano': 1,
#  'sizeism': 1,
#  'rádio': 1,
#  'bohuslav': 1,
#  'alorese': 1,
#  'murdered': 8,
#  'fonogramas': 1,
#  'fatmeh': 1,
#  'tycoon': 1,
#  'zahandeh': 1,
#  'merlon': 1,
#  'hoops': 2,
#  'intercepted': 1,
#  'pokrashen': 1,
#  'mendelssohn': 2,
#  'circular': 6,
#  'maldon': 2,
#  'reading': 63,
#  'supervising': 2,
#  'takiya': 1,
#  'betaab': 1,
#  'cerbone': 1,
#  'chartered': 6,
#  'steinwandter': 1,
#  'hsuan': 1,
#  'whole': 33,
#  'montauban': 1,
#  'waters': 25,
#  'takasu': 1,
#  'meistratzheim': 1,
#  'hilliard': 1,
#  'wyler': 1,
#  'wftda': 1,
#  'uelsby': 1,
#  'flann': 1,
#  'vishnu': 2,
#  'republicansdemocratic': 1,
#  'kwanza': 1,
#  '447000': 1,
#  'hjemkomst': 1,
#  'pixley_township': 1,
#  'gabazine': 1,
#  'playful': 1,
#  'bullimore': 1,
#  'chugoku': 1,
#  'leadley': 1,
#  '1015006907312': 1,
#  '6143049': 1,
#  'buxhall': 1,
#  'nihous': 1,
#  'statementsall': 3,
#  'erfjord': 1,
#  'linksorphaned': 2,
#  'fagui': 1,
#  'instructed': 5,
#  'amirabad': 3,
#  'botanist': 6,
#  'underspace': 1,
#  'ciphertext': 1,
#  'intermittent': 1,
#  'gemelos': 1,
#  'crawley': 2,
#  'allopregnanolone': 1,
#  'kilpatrick': 1,
#  'feuerbach': 1,
#  'badger': 1,
#  'limerick': 2,
#  'fighters': 2,
#  'plantagenet': 1,
#  'haymarket': 2,
#  'coincided': 2,
#  '500319656': 1,
#  'swamps': 4,
#  'biographisches': 1,
#  'šibenik': 1,
#  'beekeepersamerican': 1,
#  'orgevskii': 1,
#  'proclamations': 1,
#  'biccicontti': 1,
#  'articlescoordinates': 4,
#  'pluvialis': 1,
#  'pedro_machuca': 1,
#  'herwegh': 1,
#  'alternativa': 1,
#  'fingernail': 1,
#  'regret': 3,
#  'stivali': 1,
#  'performing': 26,
#  'itunes': 8,
#  'nebentan': 1,
#  'seater': 2,
#  'defining': 2,
#  'southbridge': 2,
#  '545014452': 1,
#  'bhavana': 1,
#  'advocate': 11,
#  'fault': 3,
#  'russellhidden': 1,
#  'chitin': 1,
#  'murgunde': 1,
#  'pheasant': 2,
#  'wilshausen': 1,
#  'vézannes': 1,
#  'bishopsroman': 2,
#  'bridges': 23,
#  '21921': 1,
#  'misirlou': 1,
#  'udsolgt': 1,
#  'shuanghe': 1,
#  'sludge': 2,
#  'navalvillar': 1,
#  'khurdeki': 1,
#  'aldohexoses': 1,
#  'lamlai': 1,
#  'corpus': 8,
#  'portugal': 29,
#  '00224545': 1,
#  'reedham': 1,
#  'shapeless': 1,
#  'crunkcore': 1,
#  'shiradwad': 1,
#  'sigmurethra': 1,
#  'alike': 1,
#  'europas': 1,
#  'hungarygreen': 1,
#  'caviteeducational': 1,
#  'grubauer': 1,
#  'injuring': 2,
#  'biochemistry': 2,
#  'sauropsids': 1,
#  'meridionalis': 1,
#  'fuckwitt': 1,
#  'ichabod': 1,
#  'uniform': 9,
#  'taguig': 2,
#  'giaku': 1,
#  'エイリアン': 1,
#  'black': 87,
#  'stati': 1,
#  'harrington': 3,
#  'gorge': 2,
#  'murchison': 2,
#  'shizu': 1,
#  'goffman': 2,
#  'glands': 1,
#  'solves': 2,
#  'keeler': 2,
#  '0308746101': 1,
#  'hylton': 2,
#  'dehkadeh': 2,
#  'flake': 2,
#  'nymag': 1,
#  'ghanaian': 2,
#  'levinson': 1,
#  'influenzavirus': 1,
#  'conservé': 1,
#  'sénia': 1,
#  'speculations': 1,
#  'macos': 1,
#  'gorton': 2,
#  'mcbride': 2,
#  'junjōsu': 1,
#  'arnolfo': 1,
#  'charley': 2,
#  'katscheloden': 1,
#  'ahsan': 2,
#  'saikul': 1,
#  'tantra': 1,
#  'galactic': 3,
#  'katigar': 1,
#  'forwardssport': 1,
#  'mortier': 1,
#  'hubbard': 3,
#  'oakdale': 3,
#  'winfrey': 1,
#  'kafouziéla': 1,
#  'koyluk': 1,
#  'thermplastic': 1,
#  'gamesguyana': 1,
#  'khaled_song': 1,
#  'shells': 4,
#  'muxloe': 1,
#  'peopleneoplatonistsroman': 1,
#  'cupar': 1,
#  'dameron': 1,
#  'redwater': 1,
#  'triglycosides': 1,
#  'hegra': 1,
#  'tamga': 1,
#  'статусом': 1,
#  'hinayana': 1,
#  'vivaldi': 1,
#  'dzorakap': 1,
#  'strait': 5,
#  'duration': 11,
#  'barracks': 6,
#  'milkcow': 1,
#  'blkout': 1,
#  '514446': 2,
#  'tyrant': 2,
#  'burma': 7,
#  '752176497': 1,
#  'forfeits': 1,
#  'geechy': 1,
#  'unusual': 12,
#  'footballseasons': 1,
#  'launch': 18,
#  'footsteps': 1,
#  'koogadali': 1,
#  'bravo': 7,
#  'unethical': 1,
#  'correctional': 1,
#  'gryaznov': 1,
#  'royal_navy_officer': 1,
#  'erythranthe': 1,
#  'calamonte': 1,
#  'fever': 8,
#  'ignore': 3,
#  'overviews': 2,
#  'kyoichi': 1,
#  'aakaashathile': 1,
#  'secours': 2,
#  'papuan': 1,
#  'reunión': 2,
#  'ingolsheim': 1,
#  'babbuini': 1,
#  'almagro': 1,
#  '738872607': 1,
#  '746164441': 1,
#  'dmitri': 1,
#  'vivekananda': 1,
#  'tirol': 1,
#  'séptimo': 1,
#  'timiş': 1,
#  'quarterfinals': 9,
#  'cured': 2,
#  '989084': 1,
#  'aausat': 1,
#  'badreh': 1,
#  'football': 89,
#  'burlington': 1,
#  'escalante': 1,
#  'gampo': 1,
#  'dazleh': 1,
#  'pastak': 1,
#  'ranghar': 1,
#  'mahadevan': 1,
#  'torquay': 2,
#  'convictions': 2,
#  'chocho': 1,
#  '2014orphaned': 1,
#  '86778': 1,
#  'mordasini': 1,
#  'buyback': 1,
#  'effigies': 1,
#  'phytopathologie': 1,
#  'motahhar': 1,
#  'yaddalabhavi': 1,
#  'ramziyeh': 1,
#  'arena': 24,
#  'surnamed': 1,
#  'tamaulipas': 1,
#  'hidehito': 1,
#  'shoalwater': 1,
#  'bemerkungen': 1,
#  'expelling': 1,
#  'laiyolo': 1,
#  'loner': 2,
#  'intervals': 1,
#  'scroll': 2,
#  'fitzhubert': 1,
#  'guimaraes': 1,
#  'malki': 3,
#  '748903913': 1,
#  'goorwich': 1,
#  'ramstein': 1,
#  'escamilla': 1,
#  'københavn': 1,
#  'sustainable': 11,
#  'gosabal': 1,
#  'trapani': 2,
#  '1086558': 1,
#  'input': 1,
#  'proglumide': 1,
#  'hehir': 1,
#  'tread': 1,
#  'variegated': 1,
#  'onygenaleseurotiomycetes': 1,
#  'leapt': 1,
#  'stabbing': 1,
#  '0812840178': 1,
#  'illiciaceae': 1,
#  'countyhidden': 1,
#  'sirri': 1,
#  'badachi': 1,
#  'oldhafer': 1,
#  'coventry': 9,
#  'posto': 1,
#  'sizzlers': 1,
#  'albee': 1,
#  'exosat': 1,
#  'florencio': 1,
#  'norwood': 4,
#  'compression2015': 1,
#  'ranki': 1,
#  'triptolemus_evrychou': 1,
#  'morigami': 1,
#  'schuler': 1,
#  'iniéstola': 1,
#  'frontrunners': 1,
#  'jarnik': 1,
#  'talas': 2,
#  'conforming': 1,
#  'grandidieria': 1,
#  'enciklopedija': 1,
#  'believable': 1,
#  'mulligan': 4,
#  'dickey': 5,
#  'guduvancheri': 1,
#  'tholon': 1,
#  'dixmont': 1,
#  'kesseldorf': 1,
#  'noorpur': 1,
#  'potoli': 1,
#  'myrsiniotissa': 1,
#  'kummerow': 1,
#  'approaches': 11,
#  'included': 96,
#  'lalemant': 1,
#  'tobin': 2,
#  '257610': 1,
#  'bigscreen': 1,
#  'kurama': 1,
#  'nafarelin': 1,
#  '09917': 1,
#  'bracke': 1,
#  'grenadier': 1,
#  'seeger': 1,
#  'flour': 2,
#  'moura': 1,
#  'protested': 2,
#  'finalists': 4,
#  'pennapiedimonte': 1,
#  'celebrations': 3,
#  '768266464': 1,
#  'superseded': 1,
#  'derelict': 2,
#  '20041389': 1,
#  'accusing': 4,
#  'wikifyarticles': 5,
#  'clarified': 2,
#  'kurisil': 1,
#  '31528': 1,
#  'hopefully': 1,
#  'sigha': 1,
#  'sakata': 1,
#  'установлены': 1,
#  'montépreux': 2,
#  'barbican': 1,
#  'overheating': 1,
#  'livia': 1,
#  'rowes': 1,
#  'knockout': 4,
#  'shang': 1,
#  'humanity': 4,
#  'montenegrin': 1,
#  'kanufi': 1,
#  'longworth': 1,
#  'suttas': 1,
#  'gensou': 1,
#  'groveland': 1,
#  'brosin': 1,
#  'expenditures': 1,
#  'mowbray': 2,
#  'schumpeterian': 1,
#  'demonstrates': 4,
#  'friends': 36,
#  'nisbett': 1,
#  'turin': 3,
#  'brinkley': 3,
#  'schwabachbarons': 1,
#  'præriens': 1,
#  'northfleet': 1,
#  'mesp2': 1,
#  'sutcliffe': 1,
#  'owarinaki': 1,
#  'cancel': 1,
#  'debated': 3,
#  'coquitlam': 1,
#  'slayings': 1,
#  'tabitha': 2,
#  'maropitant': 1,
#  'clarendon': 4,
#  'sankey': 1,
#  'pääjärvi': 1,
#  'procureurs': 1,
#  'chhatrasal': 1,
#  'uttarakhand': 1,
#  'polly': 3,
#  'naduhigh': 1,
#  'trinidense': 1,
#  'veterinarian': 1,
#  'hcardsall': 9,
#  'winnipeg': 5,
#  'glinka_': 1,
#  'segon': 1,
#  'croats': 2,
#  'yugoslavia1943': 1,
#  'centralbank': 1,
#  'responds': 2,
#  'badora': 1,
#  'sociologie': 1,
#  'eshgaft': 1,
#  'wealth': 6,
#  'frappé': 1,
#  'identities': 88,
#  'thaana': 1,
#  'picture': 20,
#  'bundela': 1,
#  'pancho': 2,
#  'mandoli': 2,
#  'bahasa': 1,
#  'turnstile': 1,
#  'meadows': 6,
#  'delights': 1,
#  'gaurav': 1,
#  'allblacks': 1,
#  'regionsflora': 1,
#  'warszawskiej': 1,
#  'arabian': 3,
#  'mondement': 2,
#  'rioja': 1,
#  'view_item': 1,
#  'cadusafos': 1,
#  'winterlude': 1,
#  'e_olya': 1,
#  'literate': 1,
#  'chunkur': 1,
#  'mahishwadgi': 1,
#  'nicoll': 2,
#  'shihoro': 1,
#  'izmaylovo': 1,
#  'mailing': 2,
#  'kondoa': 1,
#  'fermare': 1,
#  'cropping': 1,
#  'tortricinae': 1,
#  'stetka': 1,
#  'california2017': 1,
#  'childish': 1,
#  'mayurbhanj': 1,
#  'babilonia': 1,
#  'alimorad': 1,
#  'gansneder': 1,
#  'pathologies': 2,
#  'eskişehir': 2,
#  'expeditionfalklands': 1,
#  'landlords': 1,
#  'rosenthal': 2,
#  'fountain': 3,
#  'murder': 26,
#  'discharged': 1,
#  'pamta': 1,
#  'satipatthana': 1,
#  'mudita': 1,
#  'sulagaon': 1,
#  'antlitz': 1,
#  'saraain': 1,
#  'g03xa': 1,
#  'audrie': 1,
#  'surrounds': 2,
#  'enrollments': 1,
#  'clefayt': 1,
#  'gryziecka': 1,
#  'makuuchi': 1,
#  'midwest': 4,
#  'scissor': 1,
#  'khalil': 4,
#  'lathe': 1,
#  'khallet': 1,
#  'roxbury_presbyterian_church': 1,
#  'liesl': 1,
#  'prudence': 2,
#  'kunjra': 1,
#  'relax': 3,
#  'pathological': 1,
#  'kellogg': 5,
#  'behan': 2,
#  'ewert': 1,
#  'norsham': 1,
#  '73444': 1,
#  'artpetroglyphspre': 1,
#  'alkyl': 1,
#  'figured': 2,
#  'escaped': 12,
#  'stomata': 1,
#  'malcher': 1,
#  'stafftuck': 1,
#  'guangdong': 2,
#  'sa_re_ga_ma_pa_challenge_usa_2008': 1,
#  '1859pyraustinaepyraustinae': 1,
#  'jørgen': 2,
#  'anatta': 1,
#  'sinking': 4,
#  'baysox': 1,
#  'murun': 1,
#  'zahler': 2,
#  'kolkata': 5,
#  'regimental': 4,
#  'kankakee': 1,
#  'albeit': 4,
#  'warhapur': 1,
#  'chamvres': 1,
#  'mcdermott': 3,
#  'pentagon': 2,
#  'tennessee': 18,
#  'psycho': 2,
#  'sewers': 1,
#  'aqueduct': 1,
#  'monocotyledonous': 1,
#  'fertilizer': 2,
#  'panties': 1,
#  'diagnose': 1,
#  'seriesenglish': 1,
#  'karimabad': 4,
#  'lingering': 1,
#  'disordersmalnutritionsteatorrhea': 1,
#  'strangways': 2,
#  'hofmannsthal': 1,
#  'command': 27,
#  'năstase': 1,
#  'george_ellicott': 1,
#  'rajshri': 1,
#  'lambrigg': 1,
#  'divided': 25,
#  'kansasnorth': 1,
#  'amagá': 1,
#  'llarenas': 1,
#  'strathburn': 1,
#  'bulls': 3,
#  'leptacline': 1,
#  'paisin': 1,
#  'tomba': 1,
#  'paintersgerman': 1,
#  'philly': 2,
#  'merten': 1,
#  'bachanakeri': 1,
#  'creators': 3,
#  'puncheon': 1,
#  'sopot': 1,
#  'fragoso': 1,
#  'annotations': 2,
#  'relaxation': 2,
#  'himna': 1,
#  'stjørdal': 1,
#  'garazh': 1,
#  '14737159': 1,
#  '12_western_collegiate_hockey_association_women': 1,
#  'significant': 50,
#  'selayar': 1,
#  'populous': 1,
#  'sehwag': 1,
#  'cecropia': 1,
#  'tb01661': 1,
#  'ituango': 1,
#  'ditter': 1,
#  'ramallo': 2,
#  'beric': 1,
#  'people1956': 1,
#  'amasia': 1,
#  'suwannee': 1,
#  'texasamerican': 1,
#  'aae62f52': 1,
#  'betasur': 1,
#  'kanakomyrtus': 1,
#  'align': 3,
#  'sasikumar': 4,
#  'nissan': 2,
#  'miranda': 4,
#  'deathsgovernors': 1,
#  'visitation': 3,
#  'matigachha': 1,
#  'benzazepines': 1,
#  'konywa': 1,
#  'pussycat': 1,
#  'dacia': 1,
#  '105113': 1,
#  'drachenhöhle': 1,
#  'denieville': 1,
#  'kawaala': 1,
#  'bechan': 1,
#  'undiscernable': 1,
#  'submit': 6,
#  'keighley': 2,
#  'jarrett': 1,
#  'bobechko': 1,
#  'pumpkinhead': 1,
#  'tanenbaum': 1,
#  'souffel': 1,
#  'venkateshnagar': 1,
#  'yugoslavian': 1,
#  'vanurid': 1,
#  'épineau': 1,
#  'bombay': 5,
#  'betne': 1,
#  'anadyr': 1,
#  'zanguldar': 1,
#  'kyoko': 1,
#  'jacobson': 2,
#  'vaikunthnathji': 1,
#  'grabowski': 1,
#  'educates': 2,
#  'typearticles': 2,
#  'sulpiride': 1,
#  'lebkowski': 1,
#  'thani': 2,
#  'swedenwindows': 1,
#  'madawal': 1,
#  'marila': 2,
#  'otenzepad': 1,
#  'roknabad': 1,
#  'mazzucato': 1,
#  'devalapur': 1,
#  'heukrodt': 1,
#  'picksnc': 1,
#  '641429612': 1,
#  'lowellville': 1,
#  'kassel': 3,
#  'commercialappeal': 1,
#  'orphan': 36,
#  'châtelraould': 2,
#  'hindol': 1,
#  'autonomous': 12,
#  'distances': 6,
#  'versi': 1,
#  '51732': 1,
#  'tapering': 1,
#  'chichey': 2,
#  'summary': 35,
#  'boyzone': 1,
#  'keevil': 1,
#  'stoppin': 1,
#  'maplewood': 3,
#  'sibay': 1,
#  '46372': 1,
#  'félix': 3,
#  'titus': 2,
#  'invitations': 2,
#  'turtledove': 1,
#  'pandionidae': 1,
#  '65000': 1,
#  'compliance': 7,
#  'marcello': 4,
#  'maitland': 4,
#  'discover': 17,
#  'bafan': 1,
#  'outward': 1,
#  'diethylstilbestrol': 1,
#  'skuas': 1,
#  '721263393': 1,
#  'drowning': 4,
#  'tubruk': 1,
#  'tryline': 1,
#  'fujiko': 1,
#  'norton': 11,
#  'arahant': 1,
#  'teamtennis': 1,
#  'granges': 2,
#  'seychellois': 1,
#  'futur': 1,
#  'güell': 1,
#  'plena': 1,
#  'lütjens': 1,
#  'bozek': 1,
#  'casemates': 1,
#  'hexedrone': 1,
#  'cuban': 4,
#  'supérieure': 2,
#  '035424': 1,
#  'jokes': 5,
#  'sainz': 1,
#  'scrum': 2,
#  'sugars': 1,
#  'pensiero': 1,
#  'friedolsheim': 1,
#  'sallyangie': 1,
#  'nakkeeran': 1,
#  'firstständerhaus': 1,
#  'platyrhynchos': 1,
#  'khartoum': 2,
#  'englandathletes': 1,
#  'optique': 1,
#  'arrangement': 10,
#  'fritz': 12,
#  '04034': 1,
#  'renoir': 3,
#  'captured': 22,
#  'worman': 1,
#  'cyclones': 4,
#  'clover': 2,
#  'acidic': 2,
#  'falster': 1,
#  'marqueis': 1,
#  'kootstra': 1,
#  'kusej': 1,
#  'motivation': 3,
#  '754787179': 1,
#  'abyzov': 1,
#  'drummersbritish': 1,
#  'sumerian': 1,
#  'disruptiveness': 1,
#  'comic': 14,
#  'trends': 6,
#  'gorby': 1,
#  'alavoneh': 1,
#  'aïstopoda': 1,
#  'reuves': 2,
#  'buginese': 1,
#  'lamenting': 1,
#  'chicago': 51,
#  'kissi': 1,
#  'vlach': 1,
#  'assets': 8,
#  'gianniny': 1,
#  'brokedown': 1,
#  'physicistsfellows': 1,
#  'dalla': 1,
#  'razorbill': 1,
#  'sugababes': 1,
#  'rowdies': 1,
#  'dusp13b': 1,
#  'svecica': 1,
#  'anyutka': 1,
#  'picola': 1,
#  'laycock': 1,
#  'galatasaray': 1,
#  'wasmuth': 1,
#  'eights': 1,
#  'magnificient': 1,
#  'neisseria': 1,
#  'unsecured': 1,
#  'uranium': 1,
#  '06861': 1,
#  'uxoris': 1,
#  'comfortable': 3,
#  'ménamba': 1,
#  'kafka': 2,
#  'саратова': 1,
#  'laxopa': 1,
#  '743565478': 1,
#  'maticins': 1,
#  'dolkart': 1,
#  'vesamicol': 1,
#  'recalling': 3,
#  'cricketer': 10,
#  'catamounts': 1,
#  'coccineus': 1,
#  'gareh': 1,
#  'jermaine': 1,
#  'yorkpeople': 1,
#  'caper': 1,
#  'zydeco': 1,
#  'mondal': 2,
#  'ptprm': 1,
#  'davenport': 4,
#  'lexinton': 1,
#  'erupts': 1,
#  'iguaçu': 1,
#  'melikyan': 1,
#  '2012publications': 1,
#  'premier': 28,
#  'shukran': 1,
#  'equiano': 1,
#  'russian_party_in_estonia': 1,
#  'ceratophyllaceae': 1,
#  'coaches': 19,
#  'novela': 1,
#  'pizzolanti': 1,
#  'offences': 1,
#  'seiro': 1,
#  'gopenmol': 1,
#  'shield': 7,
#  '118743627': 1,
#  'forceps': 1,
#  'sodomy': 1,
#  'speciesendemic': 2,
#  'mackinlay': 1,
#  'overkill': 1,
#  '75098': 1,
#  'voipreux': 2,
#  'relaunch': 1,
#  '1975tillomorphini': 1,
#  '732417725': 1,
#  'prunariu': 1,
#  'sullivan': 13,
#  'heirs': 1,
#  'seismological': 1,
#  'perez': 6,
#  'timberline': 1,
#  '766364950': 1,
#  '94667': 1,
#  'publicize': 1,
#  'quchun': 1,
#  'pavilion': 7,
#  'breitenau': 1,
#  'alumnicolombian': 1,
#  'racemorphan': 1,
#  '43724': 1,
#  'tybee': 1,
#  'stubsarchaeological': 1,
#  'embellished': 1,
#  'cookies': 1,
#  'batagay': 1,
#  'after': 297,
#  '9129410355': 1,
#  'cavity': 3,
#  'hafernik': 1,
#  'shindholi': 1,
#  '593300': 1,
#  '10389': 1,
#  'bengt': 1,
#  'manly': 1,
#  'willeroon': 1,
#  'sherrill': 1,
#  'baconnes': 2,
#  'hubler': 1,
#  'varlet': 1,
#  'línea': 1,
#  'recuenco': 1,
#  'epshidden': 1,
#  'mannerist': 1,
#  'skanderborg': 1,
#  'jewell': 1,
#  'association': 129,
#  'bozen': 1,
#  'norales': 1,
#  'pamidimukkala': 1,
#  'homestyle': 1,
#  'muscles': 2,
#  'elinor': 1,
#  'onhnebok': 1,
#  'trulia': 1,
#  'mahajani': 1,
#  'freemason': 1,
#  'salesman': 4,
#  'dictators': 1,
#  'louvre': 1,
#  'nonlinear': 1,
#  'athenaeus': 1,
#  'chippenham': 3,
#  'chesterfield': 7,
#  'assortment': 2,
#  'wider': 7,
#  'dehydrocholesterol': 1,
#  '743525349': 1,
#  'handyanwadi': 1,
#  'maharashtramarathi': 1,
#  'anshei': 1,
#  'bromantane': 1,
#  'jahadabad': 1,
#  'edges': 3,
#  'els_dottermans': 1,
#  'republished': 2,
#  'gunaratana': 1,
#  'separation': 10,
#  'gabaldon': 1,
#  'artistsfemale': 1,
#  'nobly': 1,
#  'consett': 2,
#  'universitaires': 1,
#  'partenope': 1,
#  'elicit': 3,
#  'coors': 2,
#  'saktigarh': 1,
#  'cabangan': 1,
#  'títlingur': 1,
#  'news_detail': 1,
#  'dichloromethylphenidate': 1,
#  'theatricals': 1,
#  'galeana': 1,
#  'karvinkop': 1,
#  '765595694': 1,
#  'pollay': 1,
#  'nounproject': 1,
#  'mohlberg': 1,
#  'borovets': 1,
#  'naphthylamphetamine': 1,
#  'coxbank': 1,
#  'carepa': 1,
#  'granted': 16,
#  'homestead': 2,
#  'baptist': 10,
#  'hashkova': 1,
#  'hiroi': 1,
#  'napoleon': 5,
#  'awful': 1,
#  'spíritus': 1,
#  'kimeh': 1,
#  'calif': 2,
#  'breisach': 1,
#  'themed': 5,
#  'humorist': 1,
#  ...}

# %%
sorted(word_counts.items(), key=lambda x: (-x[1], x[0]))
# Out:
# [('wikipedia', 337),
#  ('retrieved', 170),
#  ('articles', 147),
#  ('categories', 123),
#  ('article', 86),
#  ('species', 69),
#  ('county', 62),
#  ('united', 54),
#  ('family', 48),
#  ('university', 48),
#  ('school', 41),
#  ('state', 41),
#  ('sources', 40),
#  ('football', 37),
#  ('september', 36),
#  ('states', 36),
#  ('district', 34),
#  ('title', 34),
#  ('world', 34),
#  ('april', 31),
#  ('national', 31),
#  ('american', 30),
#  ('north', 30),
#  ('february', 27),
#  ('south', 27),
#  ('village', 27),
#  ('which', 27),
#  ('career', 26),
#  ('population', 26),
#  ('album', 25),
#  ('december', 25),
#  ('november', 25),
#  ('march', 24),
#  ('music', 24),
#  ('station', 24),
#  ('external', 23),
#  ('french', 23),
#  ('german', 23),
#  ('january', 22),
#  ('league', 22),
#  ('october', 22),
#  ('women', 22),
#  ('australian', 20),
#  ('first', 20),
#  ('season', 20),
#  ('california', 19),
#  ('coordinates', 19),
#  ('india', 19),
#  ('british', 18),
#  ('identifierswikipedia', 18),
#  ('party', 18),
#  ('river', 18),
#  ('television', 18),
#  ('august', 17),
#  ('history', 17),
#  ('their', 17),
#  ('after', 16),
#  ('birth', 16),
#  ('member', 16),
#  ('other', 16),
#  ('census', 15),
#  ('century', 15),
#  ('church', 15),
#  ('released', 15),
#  ('series', 15),
#  ('building', 14),
#  ('central', 14),
#  ('company', 14),
#  ('group', 14),
#  ('historic', 14),
#  ('island', 14),
#  ('lacking', 14),
#  ('province', 14),
#  ('register', 14),
#  ('service', 14),
#  ('there', 14),
#  ('william', 14),
#  ('about', 13),
#  ('genus', 13),
#  ('language', 13),
#  ('original', 13),
#  ('records', 13),
#  ('stations', 13),
#  ('white', 13),
#  ('albums', 12),
#  ('championship', 12),
#  ('college', 12),
#  ('country', 12),
#  ('germany', 12),
#  ('great', 12),
#  ('house', 12),
#  ('international', 12),
#  ('islands', 12),
#  ('people', 12),
#  ('railway', 12),
#  ('references', 12),
#  ('region', 12),
#  ('track', 12),
#  ('union', 12),
#  ('water', 12),
#  ('division', 11),
#  ('general', 11),
#  ('hockey', 11),
#  ('james', 11),
#  ('links', 11),
#  ('places', 11),
#  ('remove', 11),
#  ('songs', 11),
#  ('texas', 11),
#  ('biography', 10),
#  ('canada', 10),
#  ('center', 10),
#  ('championships', 10),
#  ('chart', 10),
#  ('chinese', 10),
#  ('class', 10),
#  ('festival', 10),
#  ('indian', 10),
#  ('information', 10),
#  ('related', 10),
#  ('republic', 10),
#  ('russian', 10),
#  ('spain', 10),
#  ('times', 10),
#  ('unranked', 10),
#  ('additional', 9),
#  ('columbia', 9),
#  ('danish', 9),
#  ('david', 9),
#  ('development', 9),
#  ('election', 9),
#  ('elections', 9),
#  ('empty', 9),
#  ('england', 9),
#  ('english', 9),
#  ('field', 9),
#  ('george', 9),
#  ('government', 9),
#  ('index', 9),
#  ('municipality', 9),
#  ('parliament', 9),
#  ('played', 9),
#  ('robert', 9),
#  ('science', 9),
#  ('social', 9),
#  ('spanish', 9),
#  ('academy', 8),
#  ('actor', 8),
#  ('aircraft', 8),
#  ('australia', 8),
#  ('battle', 8),
#  ('bishop', 8),
#  ('black', 8),
#  ('carolina', 8),
#  ('communities', 8),
#  ('cricket', 8),
#  ('director', 8),
#  ('encyclopedia', 8),
#  ('france', 8),
#  ('italian', 8),
#  ('japanese', 8),
#  ('learn', 8),
#  ('location', 8),
#  ('museum', 8),
#  ('names', 8),
#  ('number', 8),
#  ('production', 8),
#  ('radio', 8),
#  ('rural', 8),
#  ('single', 8),
#  ('sports', 8),
#  ('street', 8),
#  ('system', 8),
#  ('township', 8),
#  ('actress', 7),
#  ('airport', 7),
#  ('archived', 7),
#  ('awards', 7),
#  ('catholic', 7),
#  ('creek', 7),
#  ('described', 7),
#  ('grand', 7),
#  ('greek', 7),
#  ('ireland', 7),
#  ('japan', 7),
#  ('journal', 7),
#  ('located', 7),
#  ('london', 7),
#  ('marine', 7),
#  ('military', 7),
#  ('parties', 7),
#  ('plant', 7),
#  ('political', 7),
#  ('president', 7),
#  ('queen', 7),
#  ('review', 7),
#  ('round', 7),
#  ('rugby', 7),
#  ('saint', 7),
#  ('singles', 7),
#  ('society', 7),
#  ('square', 7),
#  ('structure', 7),
#  ('students', 7),
#  ('thomas', 7),
#  ('williams', 7),
#  ('assembly', 6),
#  ('athletics', 6),
#  ('baseball', 6),
#  ('basketball', 6),
#  ('billboard', 6),
#  ('blues', 6),
#  ('board', 6),
#  ('charles', 6),
#  ('chicago', 6),
#  ('court', 6),
#  ('design', 6),
#  ('drama', 6),
#  ('engineering', 6),
#  ('event', 6),
#  ('force', 6),
#  ('format', 6),
#  ('foundation', 6),
#  ('green', 6),
#  ('latin', 6),
#  ('liberal', 6),
#  ('living', 6),
#  ('mayor', 6),
#  ('medal', 6),
#  ('palace', 6),
#  ('poland', 6),
#  ('portuguese', 6),
#  ('public', 6),
#  ('racing', 6),
#  ('romania', 6),
#  ('royal', 6),
#  ('scottish', 6),
#  ('short', 6),
#  ('smith', 6),
#  ('stage', 6),
#  ('unincorporated', 6),
#  ('virginia', 6),
#  ('western', 6),
#  ('winter', 6),
#  ('works', 6),
#  ('writer', 6),
#  ('years', 6),
#  ('against', 5),
#  ('allen', 5),
#  ('association', 5),
#  ('award', 5),
#  ('between', 5),
#  ('bridge', 5),
#  ('brown', 5),
#  ('bulgaria', 5),
#  ('business', 5),
#  ('canadian', 5),
#  ('cerambycidae', 5),
#  ('character', 5),
#  ('children', 5),
#  ('clade', 5),
#  ('coast', 5),
#  ('community', 5),
#  ('concern', 5),
#  ('council', 5),
#  ('defense', 5),
#  ('department', 5),
#  ('during', 5),
#  ('dutch', 5),
#  ('eastern', 5),
#  ('education', 5),
#  ('episodes', 5),
#  ('established', 5),
#  ('films', 5),
#  ('games', 5),
#  ('given', 5),
#  ('gmina', 5),
#  ('hospital', 5),
#  ('illinois', 5),
#  ('italy', 5),
#  ('joseph', 5),
#  ('junior', 5),
#  ('lakes', 5),
#  ('master', 5),
#  ('miles', 5),
#  ('minister', 5),
#  ('mountain', 5),
#  ('municipal', 5),
#  ('nations', 5),
#  ('norwegian', 5),
#  ('novel', 5),
#  ('oregon', 5),
#  ('point', 5),
#  ('polish', 5),
#  ('politician', 5),
#  ('portal', 5),
#  ('producer', 5),
#  ('published', 5),
#  ('record', 5),
#  ('research', 5),
#  ('results', 5),
#  ('richard', 5),
#  ('right', 5),
#  ('roman', 5),
#  ('schools', 5),
#  ('served', 5),
#  ('southern', 5),
#  ('sport', 5),
#  ('stadium', 5),
#  ('statistics', 5),
#  ('switzerland', 5),
#  ('tamil', 5),
#  ('temple', 5),
#  ('valley', 5),
#  ('video', 5),
#  ('website', 5),
#  ('wisconsin', 5),
#  ('zealand', 5),
#  ('accessed', 4),
#  ('africa', 4),
#  ('airports', 4),
#  ('arabic', 4),
#  ('arkansas', 4),
#  ('avenue', 4),
#  ('beijing', 4),
#  ('books', 4),
#  ('brothers', 4),
#  ('charts', 4),
#  ('china', 4),
#  ('citations', 4),
#  ('clubs', 4),
#  ('coach', 4),
#  ('comedy', 4),
#  ('comics', 4),
#  ('conference', 4),
#  ('construction', 4),
#  ('czech', 4),
#  ('darreh', 4),
#  ('death', 4),
#  ('dictionary', 4),
#  ('directed', 4),
#  ('distribution', 4),
#  ('earth', 4),
#  ('edition', 4),
#  ('executive', 4),
#  ('geographic', 4),
#  ('georgia', 4),
#  ('giants', 4),
#  ('goals', 4),
#  ('google', 4),
#  ('gordon', 4),
#  ('guitar', 4),
#  ('harry', 4),
#  ('historical', 4),
#  ('human', 4),
#  ('johnny', 4),
#  ('johnson', 4),
#  ('jones', 4),
#  ('kansas', 4),
#  ('kenny', 4),
#  ('kentucky', 4),
#  ('kingdom', 4),
#  ('known', 4),
#  ('labour', 4),
#  ('larvae', 4),
#  ('legislative', 4),
#  ('magazine', 4),
#  ('management', 4),
#  ('massachusetts', 4),
#  ('media', 4),
#  ('medical', 4),
#  ('metres', 4),
#  ('minnesota', 4),
#  ('mount', 4),
#  ('movie', 4),
#  ('natural', 4),
#  ('network', 4),
#  ('notability', 4),
#  ('office', 4),
#  ('official', 4),
#  ('olympic', 4),
#  ('olympics', 4),
#  ('opened', 4),
#  ('order', 4),
#  ('painter', 4),
#  ('performance', 4),
#  ('place', 4),
#  ('please', 4),
#  ('power', 4),
#  ('premier', 4),
#  ('press', 4),
#  ('produced', 4),
#  ('program', 4),
#  ('project', 4),
#  ('protein', 4),
#  ('punjab', 4),
#  ('queensland', 4),
#  ('recorded', 4),
#  ('route', 4),
#  ('rules', 4),
#  ('second', 4),
#  ('section', 4),
#  ('security', 4),
#  ('services', 4),
#  ('ships', 4),
#  ('sierra', 4),
#  ('silver', 4),
#  ('singer', 4),
#  ('small', 4),
#  ('sofla', 4),
#  ('soviet', 4),
#  ('space', 4),
#  ('status', 4),
#  ('story', 4),
#  ('studio', 4),
#  ('summer', 4),
#  ('super', 4),
#  ('surname', 4),
#  ('swiss', 4),
#  ('template', 4),
#  ('theatre', 4),
#  ('these', 4),
#  ('toronto', 4),
#  ('total', 4),
#  ('tournament', 4),
#  ('translation', 4),
#  ('using', 4),
#  ('version', 4),
#  ('villa', 4),
#  ('villages', 4),
#  ('voivodeship', 4),
#  ('wales', 4),
#  ('washington', 4),
#  ('without', 4),
#  ('young', 4),
#  ('alabama', 3),
#  ('analysis', 3),
#  ('angeles', 3),
#  ('argentina', 3),
#  ('atlantic', 3),
#  ('austria', 3),
#  ('aviation', 3),
#  ('baltimore', 3),
#  ('basin', 3),
#  ('before', 3),
#  ('berlin', 3),
#  ('border', 3),
#  ('boston', 3),
#  ('brooklyn', 3),
#  ('bruce', 3),
#  ('bulgarian', 3),
#  ('campus', 3),
#  ('candidate', 3),
#  ('cathedral', 3),
#  ('centre', 3),
#  ('chapel', 3),
#  ('chemical', 3),
#  ('chief', 3),
#  ('clark', 3),
#  ('classic', 3),
#  ('closed', 3),
#  ('command', 3),
#  ('commission', 3),
#  ('communes', 3),
#  ('communist', 3),
#  ('companies', 3),
#  ('conservative', 3),
#  ('corporation', 3),
#  ('corps', 3),
#  ('crambidae', 3),
#  ('democratic', 3),
#  ('denmark', 3),
#  ('districts', 3),
#  ('dream', 3),
#  ('elected', 3),
#  ('episode', 3),
#  ('european', 3),
#  ('featured', 3),
#  ('featuring', 3),
#  ('fiction', 3),
#  ('florida', 3),
#  ('footballer', 3),
#  ('foreign', 3),
#  ('forest', 3),
#  ('formula', 3),
#  ('founded', 3),
#  ('geography', 3),
#  ('global', 3),
#  ('governor', 3),
#  ('grave', 3),
#  ('greens', 3),
#  ('henderson', 3),
#  ('herald', 3),
#  ('independent', 3),
#  ('individual', 3),
#  ('industrial', 3),
#  ('infantry', 3),
#  ('institute', 3),
#  ('irish', 3),
#  ('israel', 3),
#  ('jewish', 3),
#  ('jordan', 3),
#  ('jumping', 3),
#  ('karnataka', 3),
#  ('label', 3),
#  ('later', 3),
#  ('lebanon', 3),
#  ('libya', 3),
#  ('limited', 3),
#  ('literature', 3),
#  ('louisiana', 3),
#  ('mahalleh', 3),
#  ('maine', 3),
#  ('manhattan', 3),
#  ('marne', 3),
#  ('married', 3),
#  ('maryland', 3),
#  ('maría', 3),
#  ('maximus', 3),
#  ('medicine', 3),
#  ('metro', 3),
#  ('meyrick', 3),
#  ('ministry', 3),
#  ('mississippi', 3),
#  ('missouri', 3),
#  ('modern', 3),
#  ('mohammad', 3),
#  ('montana', 3),
#  ('morris', 3),
#  ('mouse', 3),
#  ('movement', 3),
#  ('native', 3),
#  ('nelson', 3),
#  ('nigeria', 3),
#  ('northern', 3),
#  ('notes', 3),
#  ('oklahoma', 3),
#  ('organization', 3),
#  ('pakistan', 3),
#  ('paris', 3),
#  ('permanent', 3),
#  ('person', 3),
#  ('philosophy', 3),
#  ('portland', 3),
#  ('portugal', 3),
#  ('position', 3),
#  ('pradesh', 3),
#  ('preceded', 3),
#  ('products', 3),
#  ('publishing', 3),
#  ('puerto', 3),
#  ('pyraloidea', 3),
#  ('qatar', 3),
#  ('rajasthan', 3),
#  ('rally', 3),
#  ('regiment', 3),
#  ('rights', 3),
#  ('rowing', 3),
#  ('russell', 3),
#  ('scotland', 3),
#  ('seasons', 3),
#  ('shahid', 3),
#  ('singh', 3),
#  ('slalom', 3),
#  ('sound', 3),
#  ('source', 3),
#  ('steel', 3),
#  ('stone', 3),
#  ('student', 3),
#  ('style', 3),
#  ('succeeded', 3),
#  ('survey', 3),
#  ('swedish', 3),
#  ('swing', 3),
#  ('sydney', 3),
#  ('systems', 3),
#  ('teams', 3),
#  ('tennis', 3),
#  ('terry', 3),
#  ('theater', 3),
#  ('tortricidae', 3),
#  ('translated', 3),
#  ('trophy', 3),
#  ('tropical', 3),
#  ('turkish', 3),
#  ('under', 3),
#  ('unsourced', 3),
#  ('urban', 3),
#  ('vancouver', 3),
#  ('victoria', 3),
#  ('vietnam', 3),
#  ('ville', 3),
#  ('walker', 3),
#  ('wayback', 3),
#  ('welsh', 3),
#  ('where', 3),
#  ('would', 3),
#  ('writing', 3),
#  ('written', 3),
#  ('yorkshire', 3),
#  ('1960s', 2),
#  ('44167', 2),
#  ('acceptor', 2),
#  ('acres', 2),
#  ('adding', 2),
#  ('affairs', 2),
#  ('again', 2),
#  ('agonists', 2),
#  ('airlines', 2),
#  ('alaska', 2),
#  ('alberta', 2),
#  ('alexander', 2),
#  ('algeria', 2),
#  ('aliabad', 2),
#  ('allmusic', 2),
#  ('along', 2),
#  ('ambassador', 2),
#  ('andrews', 2),
#  ('angela', 2),
#  ('animal', 2),
#  ('anthony', 2),
#  ('aragon', 2),
#  ('areas', 2),
#  ('arena', 2),
#  ('argonne', 2),
#  ('artist', 2),
#  ('artistic', 2),
#  ('assistant', 2),
#  ('athletic', 2),
#  ('attack', 2),
#  ('auburn', 2),
#  ('australianfootball', 2),
#  ('author', 2),
#  ('average', 2),
#  ('bangor', 2),
#  ('barcelona', 2),
#  ('based', 2),
#  ('battery', 2),
#  ('batting', 2),
#  ('became', 2),
#  ('being', 2),
#  ('beirut', 2),
#  ('belarusian', 2),
#  ('belgium', 2),
#  ('belvedere', 2),
#  ('bengal', 2),
#  ('benin', 2),
#  ('bernard', 2),
#  ('block', 2),
#  ('boats', 2),
#  ('bombers', 2),
#  ('boogie', 2),
#  ('brahma', 2),
#  ('brandt', 2),
#  ('brazil', 2),
#  ('brazilian', 2),
#  ('britain', 2),
#  ('broadcasting', 2),
#  ('brooke', 2),
#  ('brother', 2),
#  ('bruno', 2),
#  ('buildings', 2),
#  ('built', 2),
#  ('bundesliga', 2),
#  ('campaign', 2),
#  ('caribbean', 2),
#  ('carlos', 2),
#  ('castle', 2),
#  ('catalan', 2),
#  ('catalogue', 2),
#  ('chairman', 2),
#  ('challenger', 2),
#  ('champagne', 2),
#  ('champion', 2),
#  ('champions', 2),
#  ('characters', 2),
#  ('chemistry', 2),
#  ('chennai', 2),
#  ('cherry', 2),
#  ('cheshmeh', 2),
#  ('chester', 2),
#  ('chiefs', 2),
#  ('chile', 2),
#  ('christmas', 2),
#  ('châtillon', 2),
#  ('cincinnati', 2),
#  ('citation', 2),
#  ('cities', 2),
#  ('civil', 2),
#  ('classical', 2),
#  ('coins', 2),
#  ('collection', 2),
#  ('colombia', 2),
#  ('colony', 2),
#  ('comic', 2),
#  ('commonwealth', 2),
#  ('commune', 2),
#  ('composition', 2),
#  ('concert', 2),
#  ('confederate', 2),
#  ('constituencies', 2),
#  ('constituency', 2),
#  ('contains', 2),
#  ('cooper', 2),
#  ('copenhagen', 2),
#  ('coronel', 2),
#  ('could', 2),
#  ('course', 2),
#  ('crater', 2),
#  ('craters', 2),
#  ('cricketer', 2),
#  ('croatia', 2),
#  ('croatian', 2),
#  ('cross', 2),
#  ('currency', 2),
#  ('dakota', 2),
#  ('dance', 2),
#  ('database', 2),
#  ('davies', 2),
#  ('defence', 2),
#  ('defender', 2),
#  ('democrat', 2),
#  ('dennis', 2),
#  ('detention', 2),
#  ('devarajan', 2),
#  ('diego', 2),
#  ('dinamo', 2),
#  ('dinar', 2),
#  ('diocese', 2),
#  ('documentary', 2),
#  ('dolni', 2),
#  ('dorado', 2),
#  ('doubles', 2),
#  ('dresden', 2),
#  ('drive', 2),
#  ('dublin', 2),
#  ('durham', 2),
#  ('dylan', 2),
#  ('early', 2),
#  ('edmonton', 2),
#  ('effect', 2),
#  ('electoral', 2),
#  ('eliteprospects', 2),
#  ('elizabeth', 2),
#  ('encryption', 2),
#  ('engine', 2),
#  ('enzyme', 2),
#  ('erebidae', 2),
#  ('españa', 2),
#  ('evaluation', 2),
#  ('exeter', 2),
#  ('expedition', 2),
#  ('faber', 2),
#  ('factor', 2),
#  ('faroese', 2),
#  ('fashion', 2),
#  ('father', 2),
#  ('federal', 2),
#  ('female', 2),
#  ('fifth', 2),
#  ('figure', 2),
#  ('final', 2),
#  ('finish', 2),
#  ('finland', 2),
#  ('finnish', 2),
#  ('flight', 2),
#  ('flora', 2),
#  ('flowering', 2),
#  ('footballers', 2),
#  ('former', 2),
#  ('foster', 2),
#  ('fraser', 2),
#  ('friends', 2),
#  ('friendship', 2),
#  ('front', 2),
#  ('fungi', 2),
#  ('gabrovo', 2),
#  ('garden', 2),
#  ('garibaldi', 2),
#  ('genome', 2),
#  ('geometry', 2),
#  ('georgian', 2),
#  ('giovanni', 2),
#  ('glacier', 2),
#  ('goran', 2),
#  ('gorni', 2),
#  ('governorate', 2),
#  ('graham', 2),
#  ('greater', 2),
#  ('greatest', 2),
#  ('greenland', 2),
#  ('gregory', 2),
#  ('growth', 2),
#  ('guantanamo', 2),
#  ('guide', 2),
#  ('guinea', 2),
#  ('hamilton', 2),
#  ('hampshire', 2),
#  ('harrison', 2),
#  ('harvey', 2),
#  ('heaven', 2),
#  ('heights', 2),
#  ('henrique', 2),
#  ('henry', 2),
#  ('heritage', 2),
#  ('highway', 2),
#  ('hills', 2),
#  ('honor', 2),
#  ('horace', 2),
#  ('horror', 2),
#  ('horse', 2),
#  ('hours', 2),
#  ('houses', 2),
#  ('howard', 2),
#  ('hungary', 2),
#  ('hunter', 2),
#  ('image', 2),
#  ('imperial', 2),
#  ('incorporating', 2),
#  ('indiana', 2),
#  ('indians', 2),
#  ('infected', 2),
#  ('innovation', 2),
#  ('instrumental', 2),
#  ('intel', 2),
#  ('internet', 2),
#  ('jeffrey', 2),
#  ('jeremy', 2),
#  ('jerusalem', 2),
#  ('jimmy', 2),
#  ('johann', 2),
#  ('joint', 2),
#  ('keaton', 2),
#  ('kelvin', 2),
#  ('kenneth', 2),
#  ('kenya', 2),
#  ('kerala', 2),
#  ('kings', 2),
#  ('knots', 2),
#  ('knoxville', 2),
#  ('korean', 2),
#  ('kumar', 2),
#  ('kōchi', 2),
#  ('labrador', 2),
#  ('languages', 2),
#  ('launch', 2),
#  ('leaves', 2),
#  ('legal', 2),
#  ('lepidoptera', 2),
#  ('letters', 2),
#  ('levels', 2),
#  ('liberec', 2),
#  ('liberty', 2),
#  ('library', 2),
#  ('lincoln', 2),
#  ('lines', 2),
#  ('linux', 2),
#  ('local', 2),
#  ('louis', 2),
#  ('luzon', 2),
#  ('madrid', 2),
#  ('mafia', 2),
#  ('magee', 2),
#  ('major', 2),
#  ('majority', 2),
#  ('malayalam', 2),
#  ('malaysia', 2),
#  ('malta', 2),
#  ('maria', 2),
#  ('maritime', 2),
#  ('martha', 2),
#  ('martins', 2),
#  ('match', 2),
#  ('matthew', 2),
#  ('mcdonald', 2),
#  ('medien', 2),
#  ('medieval', 2),
#  ('melbourne', 2),
#  ('memorial', 2),
#  ('mental', 2),
#  ('message', 2),
#  ('metal', 2),
#  ('metallica', 2),
#  ('mexico', 2),
#  ('michael', 2),
#  ('michigan', 2),
#  ('million', 2),
#  ('milwaukee', 2),
#  ('miniseries', 2),
#  ('minor', 2),
#  ('minsk', 2),
#  ('missing', 2),
#  ('mobile', 2),
#  ('mohamed', 2),
#  ('montreal', 2),
#  ('morgan', 2),
#  ('moscow', 2),
#  ('mosque', 2),
#  ('moths', 2),
#  ('motorcycle', 2),
#  ('mumbai', 2),
#  ('munich', 2),
#  ('murder', 2),
#  ('murray', 2),
#  ('musician', 2),
#  ('nagar', 2),
#  ('nascar', 2),
#  ('nationale', 2),
#  ('needed', 2),
#  ('needing', 2),
#  ('nepal', 2),
#  ('newfoundland', 2),
#  ('newton', 2),
#  ('night', 2),
#  ('niigata', 2),
#  ('norfolk', 2),
#  ('norway', 2),
#  ('notable', 2),
#  ('ocean', 2),
#  ('officer', 2),
#  ('often', 2),
#  ('oldfield', 2),
#  ('oliver', 2),
#  ('omaha', 2),
#  ('ontario', 2),
#  ('operation', 2),
#  ('orange', 2),
#  ('ordinary', 2),
#  ('origin', 2),
#  ('pacific', 2),
#  ('pages', 2),
#  ('painting', 2),
#  ('palestinian', 2),
#  ('parallel', 2),
#  ('pasha', 2),
#  ('patrol', 2),
#  ('paulo', 2),
#  ('peace', 2),
#  ('pedro', 2),
#  ('pennsylvania', 2),
#  ('peptide', 2),
#  ('performed', 2),
#  ('peter', 2),
#  ('physics', 2),
#  ('pianist', 2),
#  ('pilot', 2),
#  ('pirates', 2),
#  ('pitcher', 2),
#  ('pittsburgh', 2),
#  ('plains', 2),
#  ('plants', 2),
#  ('platinum', 2),
#  ('player', 2),
#  ('plzeň', 2),
#  ('points', 2),
#  ('police', 2),
#  ('politics', 2),
#  ('polytechnic', 2),
#  ('pomeranian', 2),
#  ('porter', 2),
#  ('pounds', 2),
#  ('prefecture', 2),
#  ('presbyterian', 2),
#  ('present', 2),
#  ('presenter', 2),
#  ('presidential', 2),
#  ('price', 2),
#  ('prime', 2),
#  ('prince', 2),
#  ('prisons', 2),
#  ('prize', 2),
#  ('processors', 2),
#  ('productions', 2),
#  ('professor', 2),
#  ('programs', 2),
#  ('property', 2),
#  ('purpose', 2),
#  ('qaleh', 2),
#  ('quarter', 2),
#  ('quarterfinals', 2),
#  ('rabbi', 2),
#  ('rangers', 2),
#  ('raymond', 2),
#  ('referendum', 2),
#  ('referendums', 2),
#  ('regional', 2),
#  ('reims', 2),
#  ('renault', 2),
#  ('report', 2),
#  ('republican', 2),
#  ('residence', 2),
#  ('resolution', 2),
#  ('resolutions', 2),
#  ('return', 2),
#  ('reviews', 2),
#  ('revolution', 2),
#  ('ridge', 2),
#  ('rivers', 2),
#  ('romance', 2),
#  ('romanian', 2),
#  ...]

# %% [markdown]
#     Selecting the top 10 words from each article speeds up performance  lirr (19,57 seconds) versus
